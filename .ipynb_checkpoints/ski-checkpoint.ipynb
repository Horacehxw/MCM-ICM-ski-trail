# %% [markdown]
# ## Step 1: Use Google Elevation API to download data.
#
# the area is
# * lat: 41.012 - 41.135
# * lon: -111.83, -111.79
#
# At this location, the length of one degree latitude and longitude are 111053.88, 84135.15 meters respectively

# %%
# %load map.py
#!/usr/bin/env python

import googlemaps
import numpy as np
import time
import json

X_min, X_max, X_num = 41.012, 41.135, 1231
Y_min, Y_max, Y_num = -111.83, -111.79, 401
LAT_LEN, LON_LEN = 111053.88, 84135.15

# %%
def request_elevation(xmin, xmax, xinc, ymin, ymax, yinc, maxnum=500):
    
    xlist = np.linspace(xmin, xmax, xinc)
    ylist = np.linspace(ymin, ymax, yinc)
    points = [(x, y) for y in ylist for x in xlist]

    requestnum = int(np.floor(len(points) / maxnum) + 1)
    npoints = np.array_split(points, requestnum)
    
    if requestnum > 2500:
        print("Error: Request number exceed! Change grid or region.")
        return
    
    ret=[]
    for i, loc in enumerate(npoints):
        ret.append(gmaps.elevation(locations=loc.tolist()))
        time.sleep(0.05)
        if i%50==0:
            print(i,"/",len(npoints))
    return ret

# %%
'''
# 设置要下载高程数据的经度范围、纬度范围以及网格间隔
xmin, xmax, xnum = X_min, X_max, X_num
ymin, ymax, ynum = Y_min, Y_max, Y_num

gmaps = googlemaps.Client(key='API key')

# Generate all locations
elevations = request_elevation(xmin, xmax, xnum, ymin, ymax, ynum)

# output data with format `longitude latitude elevation resolution`
with open("elevations.json", "w") as f:
    json.dump(elevations, f)
'''
# Out:
# '\n# 设置要下载高程数据的经度范围、纬度范围以及网格间隔\nxmin, xmax, xnum = X_min, X_max, X_num\nymin, ymax, ynum = Y_min, Y_max, Y_num\n\ngmaps = googlemaps.Client(key=\'AIzaSyAme9sb9LJFNmpgRvx4eZDQrKfK6wyH1bE\')\n\n# Generate all locations\nelevations = request_elevation(xmin, xmax, xnum, ymin, ymax, ynum)\n\n# output data with format `longitude latitude elevation resolution`\nwith open("elevations.json", "w") as f:\n    json.dump(elevations, f)\n'

# %% [markdown]
# ## Step 2: Transform raw data into 2D array map format.
# all the latitude and longitude is round up into 4 decimal

# %%
import json
import numpy as np
import time

data = json.load(open('elevations.json'))
elevations = [x for y in data for x in y]
resolution = np.mean([x['resolution'] for x in elevations])

# %%
resolution
# Out:
# 9.0864858890625886

# %%
elevations[100]
# Out:
# {'elevation': 2650.176025390625,
#  'location': {'lat': 41.02200000000033, 'lng': -111.83},
#  'resolution': 19.08790397644043}

# %%
DECIMAL = 4 # keep all the latitude and longitude in 4 decimal round up
pos = {}
for x in elevations:
    pos[(np.around(x['location']['lat'], decimals = DECIMAL), np.around(x['location']['lng'], decimals = DECIMAL))] = x['elevation']

# %%
def generate_map(position, x_range, y_range):
    '''
    generate the coresponding z coordinate matrix based on the x, y coordinate for surface plot.
    input:
        x_range, y_range: 1D np array
        position: dictionary (x,y) --> z
    '''
    z = np.zeros((x_range.size, y_range.size))
    for i in range(0, x_range.size):
        for j in range(0, y_range.size):
            z[i, j] = position[(x_range[i], y_range[j])]
    return z

# %%
x_range = np.around(np.linspace(X_min, X_max, X_num), decimals=DECIMAL)
y_range = np.around(np.linspace(Y_min, Y_max, Y_num), decimals=DECIMAL)
z_elevation = generate_map(pos, x_range, y_range)

# %%
z_elevation.shape
# Out:
# (1231, 401)

# %%
z_elevation[1230, 400]
# Out:
# 1477.662109375

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.tools.set_credentials_file(username='user_name', api_key='API key')

trace = go.Surface(
    y = x_range,
    x = y_range,
    z = z_elevation,
    opacity = 0.8
)


layout = go.Layout(
    title='surface of ski mountain',
    xaxis = dict(
        title='longitude'
    ),
    yaxis = dict(
        title = 'latitude'
    ),
    scene = dict(
        aspectratio = dict(x=8,y=11,z=5)
    )
)

fig = go.Figure(data=[trace], layout=layout)
py.iplot(fig, filename='surface of ski mountain')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /anaconda/envs/py35/lib/python3.5/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Step 3: Ski Trace Searching Algorithm
#
# Base search:
#
# ```Python
# def Search(Point a, step r, slope s):
#     find all the point(in 36 different direction) on the cycle centered at a, radius = r.
#     claculate the slope
#     If (all slope is negative):
#         return
#     Else:
#         find the 3 point with slope closet to s
#         a.record(b,c,d)
#         search(b),search(c), search(d)
# ```
# Slope is $tan(\theta)$, which is the ratio between horizontal and vertical distance.
#
#
# Optimization:
# * Keep tracking the variance of slopes on each ski track, terminate the search in advance for those with high variance.
# * recurrence with memorization to avoid repited computation.

# %%
'''
Hyper parameter:(each list is for easy, intermediate, hard respectively)
    SLOPE: The objective slope 
    LOWER_THERSH: the lower threshold of slope where the loss function is activate
    UPPER_BOUND: the upper bound of slope where the slope can't exceed during the search algorithm runing
'''
SLOPE = [np.tan(np.pi/4.*0.155), np.tan(np.pi/4.*0.325), np.tan(np.pi/4.*0.7)] #SLOPE_EASY, SLOPE_INTERMIDIATE, SLOPE_HARD
LOWER_THRESH = [np.tan(np.pi/4.*0.06), np.tan(np.pi/4.*0.25), np.tan(np.pi/4.*0.4)]
UPPER_BOUND = [np.tan(np.pi/4.*0.25), np.tan(np.pi/4.*0.4), np.tan(np.pi/4.*1.2)]

# %%
UPPER_BOUND
# Out:
# [0.19891236737965801, 0.32491969623290629, 1.3763819204711734]

# %%
'''
DECIMAL = 4 # keep all the latitude and longitude in 4 decimal round up
x_range = np.around(np.linspace(X_min, X_max, X_num), decimals=DECIMAL)
y_range = np.around(np.linspace(Y_min, Y_max, Y_num), decimals=DECIMAL)
z_elevation = generate_map(pos, x_range, y_range)
'''
# Out:
# '\nDECIMAL = 4 # keep all the latitude and longitude in 4 decimal round up\nx_range = np.around(np.linspace(X_min, X_max, X_num), decimals=DECIMAL)\ny_range = np.around(np.linspace(Y_min, Y_max, Y_num), decimals=DECIMAL)\nz_elevation = generate_map(pos, x_range, y_range)\n'

# %%
class Point():
    '''
    This object's attribute won't change after initialization.
    '''
    def __init__(self, i, j):
        self.elevation = z_elevation[i, j]
        self.i, self.j = i,j
        self.lat = x_range[i]
        self.lon = y_range[j]

    def distance(self, other):
        '''
        Horizontal distance in meters for two points
            # !!! Ignore the height !!!
        '''
        return np.sqrt(((self.lat - other.lat)*LAT_LEN)**2 \
                    + ((self.lon - other.lon)*LON_LEN)**2)

    def slope(self, other):
        '''
        The elevation difference / horizontal distance ratio.
            If slope > 0, self is higher than other
            If slope < 0, self is lower than other
        '''
        return (self.elevation - other.elevation) / self.distance(other)

    def find_circle(self, radius, num=36):
        '''
        Find the corresonding point's index on the cycle centered at self, in specific direction
        input:
            num: number of directions to search
            radius is on meters
        output:
            list of tuple (i,j)
        '''
        ret = []
        for direction in np.linspace(0, 2*np.pi, num, endpoint=False):
            #import pdb; pdb.set_trace()
            next_i = self.i + int(np.around(radius*np.sin(direction)/(LAT_LEN*0.0001)))
            next_j = self.j + int(np.around(radius*np.cos(direction)/(LON_LEN*0.0001)))
            if next_i >= x_range.size or next_i < 0 or next_j >= y_range.size or next_j < 0:
                continue
            ret.append([next_i, next_j])
        return ret

locations = [[Point(i, j) for j in range(y_range.size)] for i in range(x_range.size)]

# %%
len(locations), len(locations[0])
# Out:
# (1231, 401)

# %%
def search(now, slope,visited, back, upper, radius=50):
    '''
    Perform the modified dfs
    '''
    ids = now.find_circle(radius)
    other_slopes = [now.slope(locations[index[0]][index[1]]) for index in ids]
    diffs = [np.abs(slope - others) for others in other_slopes]
    next_dir = np.argsort(diffs)[:3] #the 'direction' for next position with cloest slope
    for direction in next_dir: #deal with next position
        pos = ids[direction]
        # cases we don't continue the search
        if other_slopes[direction] < 0 or visited[pos[0], pos[1]] == 1 or other_slopes[direction] > upper :
            continue
        visited[pos[0], pos[1]] = 1
        back[pos[0]][pos[1]] = (now.i, now.j)
        search(locations[pos[0]][pos[1]], slope, visited, back, radius)

# %%
def find_min(visited):
    min_elevation = np.inf
    min_i, min_j = -1, -1
    for i in range(x_range.size):
        for j in range(y_range.size):
            if visited[i, j] == 1 and locations[i][j].elevation < min_elevation:
                min_i, min_j = i, j
    return min_i, min_j

def back_trace(now_i, now_j, back):
    '''
    return a path in iterable of Point object
    '''
    path = []
    while back[now_i][now_j] != (now_i, now_j):
        now = locations[now_i][now_j]
        path.append(now)
        now_i, now_j = back[now_i][now_j]
    return path

from numpy.random import randint
def random_start(num):
    '''
    Return iterable of starting index
    '''
    x_id = randint(0, x_range.size, size=num)
    y_id = randint(0, y_range.size, size=num)
    return zip(x_id, y_id)

## TO DO: change random search into parallel for loop!
from joblib import Parallel, delayed
def search_start(start, slope, upper):
    print("search start at {},{}".format(start[0],start[1]))
    visited = np.zeros((x_range.size, y_range.size))
    back = [[(i, j) for j in range(y_range.size)] for i in range(x_range.size)]
    #import pdb;pdb.set_trace()
    search(locations[start[0]][start[1]], slope, visited, back, upper) 
    path = back_trace(*find_min(visited), back=back)
    return path

def random_search(num, slope, upper):
    starts = random_start(num)
    return Parallel(n_jobs=-1)(delayed(search_start, upper)(start, slope, upper) for start in starts)

# %%
from pytictoc import TicToc
t = TicToc()
t.tic()
paths = random_search(10, SLOPE[2], UPPER_BOUND[2])
t.toc()
# Out:
# search start at 753,182
# search start at 465,171
# search start at 765,366
# search start at 646,362
# search start at 912,104
# search start at 1075,139
# search start at 792,319
# search start at 809,395
# search start at 1225,154
# search start at 660,96
# Elapsed time is 5.296069 seconds.

# %%
def generate_fig(paths, surface):
    data = [surface]
    for path in paths:
        #import pdb; pdb.set_trace()
        x = [loc.lat for loc in path]
        y = [loc.lon for loc in path]
        z = [loc.elevation for loc in path]
        path_trace = go.Scatter3d(
                        x=y, y=x, z=z,
                        marker=dict(
                            size=2,
                            color=z,
                            colorscale='Viridis',
                        ),
                        line=dict(
                            color='#1f77b4',
                            width=3
                        )
                    )
        data.append(path_trace)
    fig = go.Figure(data=data)
    return fig

# %%
fig = generate_fig(paths, trace)
py.iplot(fig, filename='surface of ski mountain')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /anaconda/envs/py35/lib/python3.5/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Step 4: Random Start Searching, Minimize the Cost function.
#
# Among the paths we randomly searched, our goal is to find those satisfy two objective:
#
#  * The trail slope is close to the given area
#
#  The hinge loss is applied, there's a linear penalty for the slopes exceeding:
#
#  $$
# f(i)=
# \begin{cases}
#  k-S_{i} & \text{ if } S_{i}<k \\
#  \infty & \text{ if } S_{i}>k'
# \end{cases}
# $$
#
# $$ L_1 = \sum_{i=1}^{N}f(i)$$
#
#  * The terrian roughness is as small as possible
#
#  We use the standard deviation of slopes on the path:
#
#  $$L_2 = \sigma_{a} ={\sqrt {{\frac {1}{N}}\sum _{i=1}^{N}(S_{i}-\bar{S})^{2}}},{\rm {\ \ where\ \ }}\bar{S} ={\frac {1}{N}}\sum _{i=1}^{N}S_{i}$$
#
# In order to get the overall loss function, we normalize each of above objective and add them together.

# %%
def cost1(path, lower):
    '''
    hinge loss of slope bias
    '''
    slope = [np.abs(path[i+1].slope(path[i])) for i in range(len(path)-1)]
    cost = [lower - s if s < lower else 0 for s in slope]
    return np.sum(cost)

def cost2(path):
    '''
    terrian roughness estimation
    '''
    if len(path) == 1:
        return 0
    slope = [np.abs(path[i+1].slope(path[i])) for i in range(len(path)-1)]
    return np.std(slope)

# %%
def length(path):
    '''
    Totla length of given path in terms of meter
    '''
    lens = [np.sqrt(path[i].distance(path[i+1])**2 + (path[i].elevation - path[i+1].elevation)**2) for i in range(len(path)-1)]
    return np.sum(lens)

# %%
from sklearn.preprocessing import normalize
def cost_total(paths, lower):
    P = 1000 # threshold to give linear penalty on length
    costs1 = normalize([cost1(path, lower) for path in paths])
    costs2 = normalize([cost2(path) for path in paths])
    costs3 = [P-length(path) if length(path)<=P else 0 for path in paths]
    return costs1 + costs2 + costs3

# %% [markdown]
# ### 4.1 Find Optimal paths for **easy,intermidiate,hard** trail
#
# randomly choose 5000 starting point and find the coresspoing paths.
#
# Find 10 best path with the smallest cost

# %%
def find_k_best(level, k=20, trial=1000):
    '''
    Take random trails and find k best path to minimize the given cost function.
    Input:
        level: the difficulty level 0-easy, 1-intermediate, 2-hard
        k: default 20, the number of best paths to return
        trail: default 5000, the number of random search taken
    return: 
        best_paths: list of path, where each path is a list of Point objects
    '''
    paths = random_search(trial, SLOPE[level], UPPER_BOUND[level])
    costs = cost_total(paths, LOWER_THRESH[level])
    indexs = np.argsort(costs)
    return indexs, paths

# %%
easy_index = np.argsort(cost_total(easy_paths, LOWER_THRESH[0]).reshape(5000))
intermidiate_index = np.argsort(cost_total(intermidiate_paths, LOWER_THRESH[1]).reshape(5000))
hard_index = np.argsort(cost_total(hard_paths, LOWER_THRESH[2]).reshape(5000))
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
t.tic()
easy_index, easy_paths = find_k_best(0)
t.toc()
# Out:
# search start at 652,95
# search start at 1193,167
# search start at 524,396
# search start at 1136,23
# search start at 351,352
# search start at 827,9
# search start at 926,82
# search start at 562,18
# search start at 9,151
# search start at 768,372
# search start at 827,302
# search start at 1200,218
# search start at 948,214
# search start at 595,120
# search start at 1215,171
# search start at 915,3
# search start at 615,230
# search start at 80,341
# search start at 944,104
# search start at 219,193
# search start at 498,140
# search start at 857,313
# search start at 264,229
# search start at 932,400
# search start at 1186,66
# search start at 993,68
# search start at 871,68
# search start at 1140,352
# search start at 57,296
# search start at 120,276
# search start at 866,183
# search start at 559,348
# search start at 365,157
# search start at 572,221
# search start at 311,288
# search start at 350,57
# search start at 890,184
# search start at 273,201
# search start at 318,351
# search start at 508,255
# search start at 554,99
# search start at 1192,31
# search start at 1069,345
# search start at 210,232
# search start at 100,283
# search start at 588,396
# search start at 1078,124
# search start at 608,184
# search start at 701,385
# search start at 1209,264
# search start at 936,64
# search start at 515,264
# search start at 65,295
# search start at 1023,76
# search start at 865,288
# search start at 842,310
# search start at 462,152
# search start at 183,50
# search start at 589,393
# search start at 238,140
# search start at 779,333
# search start at 398,277
# search start at 379,199
# search start at 1095,267
# search start at 374,1
# search start at 755,319
# search start at 872,309
# search start at 1000,370
# search start at 549,162
# search start at 130,64
# search start at 705,253
# search start at 1138,224
# search start at 622,108
# search start at 1196,327
# search start at 779,371
# search start at 368,393
# search start at 48,22
# search start at 988,82
# search start at 1177,53
# search start at 1099,54
# search start at 370,115
# search start at 595,394
# search start at 194,294
# search start at 433,33
# search start at 483,182
# search start at 646,208
# search start at 662,217
# search start at 741,52
# search start at 161,57
# search start at 1024,314
# search start at 73,88
# search start at 457,275
# search start at 109,389
# search start at 545,139
# search start at 785,370
# search start at 535,323
# search start at 486,343
# search start at 433,93
# search start at 1080,21
# search start at 1143,263
# search start at 1091,278
# search start at 492,60
# search start at 1197,26
# search start at 1005,72
# search start at 665,229
# search start at 365,300
# search start at 662,227
# search start at 1103,291
# search start at 324,274
# search start at 290,334
# search start at 166,156
# search start at 203,308
# search start at 1095,94
# search start at 704,215
# search start at 568,16
# search start at 372,382
# search start at 587,25
# search start at 768,317
# search start at 467,335
# search start at 1144,151
# search start at 1167,385
# search start at 1151,144
# search start at 1164,128
# search start at 640,239
# search start at 362,267
# search start at 765,133
# search start at 945,67
# search start at 1226,327
# search start at 192,271
# search start at 92,120
# search start at 133,131
# search start at 485,7
# search start at 450,296
# search start at 362,54
# search start at 991,148
# search start at 533,244
# search start at 84,264
# search start at 804,129
# search start at 459,285
# search start at 360,12
# search start at 794,326
# search start at 437,319
# search start at 291,333
# search start at 865,27
# search start at 856,69
# search start at 1149,27
# search start at 9,285
# search start at 766,299
# search start at 596,391
# search start at 1006,41
# search start at 1067,226
# search start at 815,361
# search start at 803,231
# search start at 1156,23
# search start at 27,124
# search start at 531,67
# search start at 804,236
# search start at 41,16
# search start at 1102,333
# search start at 1047,131
# search start at 150,249
# search start at 512,188
# search start at 298,360
# search start at 1113,378
# search start at 638,391
# search start at 750,324
# search start at 187,96
# search start at 528,154
# search start at 780,391
# search start at 922,29
# search start at 404,65
# search start at 831,137
# search start at 332,255
# search start at 183,175
# search start at 953,312
# search start at 299,54
# search start at 1215,387
# search start at 520,318
# search start at 721,253
# search start at 533,196
# search start at 1041,205
# search start at 1085,248
# search start at 740,307
# search start at 523,229
# search start at 737,317
# search start at 1185,391
# search start at 259,331
# search start at 674,261
# search start at 1209,119
# search start at 380,312
# search start at 244,381
# search start at 1103,377
# search start at 982,215
# search start at 790,308
# search start at 333,84
# search start at 398,46
# search start at 1079,115
# search start at 1122,147
# search start at 868,204
# search start at 1070,56
# search start at 233,90
# search start at 575,214
# search start at 921,188
# search start at 881,114
# search start at 111,63
# search start at 1057,213
# search start at 719,266
# search start at 919,115
# search start at 893,269
# search start at 136,347
# search start at 60,290
# search start at 959,188
# search start at 211,381
# search start at 539,360
# search start at 388,230
# search start at 1091,203
# search start at 703,156
# search start at 939,95
# search start at 1198,58
# search start at 1150,51
# search start at 174,133
# search start at 1109,340
# search start at 1143,397
# search start at 970,16
# search start at 1218,352
# search start at 144,356
# search start at 525,30
# search start at 727,226
# search start at 778,77
# search start at 1114,205
# search start at 579,336
# search start at 406,197
# search start at 426,242
# search start at 160,370
# search start at 39,135
# search start at 26,351
# search start at 1207,238
# search start at 187,331
# search start at 50,11
# search start at 1173,390
# search start at 223,253
# search start at 1063,208
# search start at 889,336
# search start at 548,118
# search start at 1170,150
# search start at 382,118
# search start at 685,294
# search start at 250,81
# search start at 1056,221
# search start at 965,163
# search start at 132,122
# search start at 571,176
# search start at 187,68
# search start at 1169,206
# search start at 164,346
# search start at 365,272
# search start at 824,163
# search start at 436,334
# search start at 1037,107
# search start at 1214,202
# search start at 264,266
# search start at 610,306
# search start at 549,255
# search start at 552,33
# search start at 1103,343
# search start at 588,298
# search start at 349,76
# search start at 914,77
# search start at 1102,23
# search start at 252,313
# search start at 1147,385
# search start at 168,357
# search start at 613,293
# search start at 1077,172
# search start at 720,47
# search start at 713,362
# search start at 598,393
# search start at 561,272
# search start at 503,165
# search start at 713,84
# search start at 301,246
# search start at 341,167
# search start at 299,266
# search start at 373,105
# search start at 370,216
# search start at 657,294
# search start at 869,301
# search start at 1171,118
# search start at 1125,130
# search start at 913,286
# search start at 96,18
# search start at 13,160
# search start at 886,304
# search start at 253,394
# search start at 550,68
# search start at 412,281
# search start at 1180,29
# search start at 849,139
# search start at 862,116
# search start at 483,246
# search start at 866,354
# search start at 81,356
# search start at 480,165
# search start at 1154,301
# search start at 1051,40
# search start at 424,1
# search start at 1153,336
# search start at 29,280
# search start at 1212,75
# search start at 510,143
# search start at 230,314
# search start at 225,266
# search start at 34,156
# search start at 898,108
# search start at 913,70
# search start at 1024,11
# search start at 758,369
# search start at 1156,301
# search start at 234,299
# search start at 1152,165
# search start at 703,360
# search start at 1223,85
# search start at 543,364
# search start at 978,384
# search start at 29,211
# search start at 372,30
# search start at 665,219
# search start at 201,177
# search start at 1148,14
# search start at 201,323
# search start at 41,396
# search start at 206,308
# search start at 1068,279
# search start at 876,395
# search start at 754,44
# search start at 1208,263
# search start at 869,133
# search start at 415,337
# search start at 459,336
# search start at 300,340
# search start at 496,346
# search start at 642,266
# search start at 318,85
# search start at 729,275
# search start at 662,33
# search start at 81,47
# search start at 527,230
# search start at 15,362
# search start at 422,98
# search start at 821,221
# search start at 124,231
# search start at 210,175
# search start at 811,63
# search start at 590,166
# search start at 762,345
# search start at 799,214
# search start at 589,383
# search start at 979,351
# search start at 1001,321
# search start at 1091,153
# search start at 81,279
# search start at 1090,203
# search start at 549,152
# search start at 421,160
# search start at 82,340
# search start at 832,303
# search start at 438,150
# search start at 1011,136
# search start at 795,170
# search start at 729,87
# search start at 871,179
# search start at 696,221
# search start at 970,172
# search start at 266,52
# search start at 1102,7
# search start at 220,239
# search start at 685,323
# search start at 443,52
# search start at 1068,353
# search start at 967,257
# search start at 199,88
# search start at 103,333
# search start at 132,186
# search start at 710,107
# search start at 486,157
# search start at 1004,12
# search start at 315,201
# search start at 914,108
# search start at 348,351
# search start at 399,240
# search start at 392,34
# search start at 1075,174
# search start at 641,195
# search start at 525,264
# search start at 553,229
# search start at 398,132
# search start at 196,110
# search start at 763,231
# search start at 1130,386
# search start at 65,181
# search start at 619,23
# search start at 766,109
# search start at 108,329
# search start at 1079,330
# search start at 140,284
# search start at 978,193
# search start at 119,281
# search start at 555,108
# search start at 346,21
# search start at 299,135
# search start at 608,137
# search start at 887,158
# search start at 228,346
# search start at 614,124
# search start at 179,307
# search start at 669,159
# search start at 952,172
# search start at 280,128
# search start at 85,163
# search start at 679,375
# search start at 965,196
# search start at 334,306
# search start at 466,175
# search start at 13,159
# search start at 959,395
# search start at 982,159
# search start at 1167,398
# search start at 1144,288
# search start at 779,261
# search start at 192,67
# search start at 1004,74
# search start at 616,216
# search start at 91,227
# search start at 458,378
# search start at 172,372
# search start at 580,56
# search start at 890,279
# search start at 439,119
# search start at 221,316
# search start at 1067,109
# search start at 556,132
# search start at 979,225
# search start at 995,241
# search start at 325,380
# search start at 237,399
# search start at 92,157
# search start at 604,219
# search start at 986,205
# search start at 373,373
# search start at 312,304
# search start at 969,376
# search start at 1166,171
# search start at 104,343
# search start at 763,227
# search start at 843,398
# search start at 151,303
# search start at 1080,131
# search start at 568,252
# search start at 507,289
# search start at 208,284
# search start at 719,66
# search start at 124,84
# search start at 882,117
# search start at 475,88
# search start at 221,252
# search start at 563,169
# search start at 689,301
# search start at 509,218
# search start at 608,216
# search start at 875,148
# search start at 93,170
# search start at 102,131
# search start at 969,73
# search start at 195,226
# search start at 203,341
# search start at 610,288
# search start at 935,271
# search start at 483,15
# search start at 902,153
# search start at 491,35
# search start at 1200,55
# search start at 948,333
# search start at 740,340
# search start at 998,143
# search start at 259,122
# search start at 798,268
# search start at 281,149
# search start at 210,135
# search start at 1088,386
# search start at 428,252
# search start at 772,161
# search start at 78,242
# search start at 840,312
# search start at 962,250
# search start at 1218,280
# search start at 848,124
# search start at 779,354
# search start at 612,387
# search start at 1015,199
# search start at 426,93
# search start at 202,50
# search start at 705,339
# search start at 356,0
# search start at 720,155
# search start at 1206,133
# search start at 611,96
# search start at 5,279
# search start at 994,219
# search start at 92,268
# search start at 1216,248
# search start at 402,169
# search start at 722,45
# search start at 105,209
# search start at 510,394
# search start at 757,267
# search start at 797,86
# search start at 1009,275
# search start at 383,369
# search start at 672,301
# search start at 49,150
# search start at 370,250
# search start at 36,278
# search start at 582,228
# search start at 1108,213
# search start at 51,200
# search start at 438,278
# search start at 266,317
# search start at 1207,222
# search start at 1148,84
# search start at 756,19
# search start at 238,303
# search start at 564,78
# search start at 1052,150
# search start at 802,261
# search start at 252,77
# search start at 568,396
# search start at 53,141
# search start at 1065,117
# search start at 420,294
# search start at 711,95
# search start at 926,339
# search start at 938,288
# search start at 664,354
# search start at 38,100
# search start at 192,31
# search start at 117,341
# search start at 610,7
# search start at 750,85
# search start at 421,264
# search start at 1192,174
# search start at 511,270
# search start at 604,55
# search start at 1093,168
# search start at 1142,345
# search start at 50,349
# search start at 342,4
# search start at 557,164
# search start at 1002,66
# search start at 313,348
# search start at 1075,57
# search start at 561,380
# search start at 207,310
# search start at 376,196
# search start at 798,340
# search start at 19,90
# search start at 802,105
# search start at 335,61
# search start at 199,209
# search start at 519,236
# search start at 1157,9
# search start at 795,381
# search start at 220,368
# search start at 1051,331
# search start at 270,172
# search start at 286,59
# search start at 322,270
# search start at 1188,202
# search start at 415,383
# search start at 917,239
# search start at 443,46
# search start at 1216,116
# search start at 541,321
# search start at 636,317
# search start at 1096,34
# search start at 454,166
# search start at 477,156
# search start at 1216,229
# search start at 776,56
# search start at 40,84
# search start at 45,281
# search start at 565,7
# search start at 1218,40
# search start at 16,129
# search start at 255,396
# search start at 160,11
# search start at 108,42
# search start at 342,49
# search start at 175,10
# search start at 201,373
# search start at 287,349
# search start at 1159,356
# search start at 40,43
# search start at 901,17
# search start at 971,352
# search start at 102,194
# search start at 555,229
# search start at 452,305
# search start at 556,366
# search start at 924,43
# search start at 209,221
# search start at 166,163
# search start at 505,77
# search start at 1168,367
# search start at 834,62
# search start at 1040,83
# search start at 645,58
# search start at 19,122
# search start at 94,158
# search start at 485,141
# search start at 86,89
# search start at 729,76
# search start at 467,14
# search start at 932,192
# search start at 1200,265
# search start at 1075,169
# search start at 1166,376
# search start at 114,24
# search start at 764,280
# search start at 741,331
# search start at 1230,357
# search start at 1026,175
# search start at 199,324
# search start at 125,155
# search start at 547,28
# search start at 607,339
# search start at 455,182
# search start at 588,328
# search start at 24,3
# search start at 935,70
# search start at 689,110
# search start at 77,5
# search start at 906,94
# search start at 123,270
# search start at 1005,227
# search start at 1139,242
# search start at 711,31
# search start at 660,159
# search start at 345,46
# search start at 143,131
# search start at 777,78
# search start at 677,9
# search start at 587,387
# search start at 854,189
# search start at 259,112
# search start at 77,235
# search start at 39,137
# search start at 202,198
# search start at 852,92
# search start at 385,189
# search start at 1084,55
# search start at 526,311
# search start at 1131,392
# search start at 587,157
# search start at 802,33
# search start at 20,273
# search start at 127,80
# search start at 841,81
# search start at 633,251
# search start at 321,204
# search start at 739,391
# search start at 938,64
# search start at 793,342
# search start at 610,56
# search start at 1205,59
# search start at 679,124
# search start at 999,171
# search start at 1066,41
# search start at 945,203
# search start at 1197,56
# search start at 182,167
# search start at 863,212
# search start at 155,24
# search start at 1021,123
# search start at 492,111
# search start at 234,356
# search start at 627,197
# search start at 27,323
# search start at 107,330
# search start at 602,58
# search start at 656,127
# search start at 619,301
# search start at 707,110
# search start at 352,230
# search start at 107,123
# search start at 156,338
# search start at 904,142
# search start at 529,387
# search start at 937,297
# search start at 75,17
# search start at 103,19
# search start at 616,256
# search start at 469,338
# search start at 1030,5
# search start at 20,323
# search start at 409,80
# search start at 1196,212
# search start at 1139,322
# search start at 367,146
# search start at 177,55
# search start at 263,352
# search start at 1112,50
# search start at 419,377
# search start at 980,111
# search start at 451,77
# search start at 787,312
# search start at 970,35
# search start at 32,161
# search start at 1013,173
# search start at 136,207
# search start at 1120,121
# search start at 687,100
# search start at 1183,206
# search start at 43,229
# search start at 788,351
# search start at 587,230
# search start at 563,360
# search start at 591,341
# search start at 745,32
# search start at 132,78
# search start at 627,231
# search start at 825,313
# search start at 616,344
# search start at 353,97
# search start at 552,77
# search start at 372,43
# search start at 889,352
# search start at 408,336
# search start at 818,223
# search start at 43,119
# search start at 803,24
# search start at 134,286
# search start at 519,328
# search start at 36,330
# search start at 187,200
# search start at 792,106
# search start at 172,218
# search start at 1180,147
# search start at 840,267
# search start at 68,365
# search start at 106,245
# search start at 131,363
# search start at 800,321
# search start at 1142,68
# search start at 600,274
# search start at 180,65
# search start at 418,318
# search start at 664,327
# search start at 1022,285
# search start at 1226,234
# search start at 390,195
# search start at 552,311
# search start at 213,3
# search start at 151,98
# search start at 1191,189
# search start at 1166,208
# search start at 953,260
# search start at 925,215
# search start at 561,258
# search start at 623,81
# search start at 504,46
# search start at 738,228
# search start at 923,237
# search start at 1204,80
# search start at 41,386
# search start at 165,199
# search start at 530,197
# search start at 439,298
# search start at 157,114
# search start at 1215,230
# search start at 455,99
# search start at 732,256
# search start at 241,13
# search start at 1129,197
# search start at 830,53
# search start at 1045,348
# search start at 1027,66
# search start at 616,312
# search start at 525,198
# search start at 440,49
# search start at 679,68
# search start at 656,23
# search start at 95,48
# search start at 946,357
# search start at 890,118
# search start at 816,5
# search start at 745,9
# search start at 1083,324
# search start at 678,335
# search start at 36,397
# search start at 1020,3
# search start at 700,221
# search start at 65,73
# search start at 324,352
# search start at 530,175
# search start at 463,83
# search start at 523,266
# search start at 324,65
# search start at 826,100
# search start at 668,146
# search start at 644,330
# search start at 1174,316
# search start at 162,288
# search start at 119,277
# search start at 321,103
# search start at 539,111
# search start at 941,193
# search start at 823,182
# search start at 269,319
# search start at 1154,331
# search start at 897,117
# search start at 228,66
# search start at 450,263
# search start at 672,186
# search start at 267,190
# search start at 1084,352
# search start at 799,77
# search start at 426,34
# search start at 184,313
# search start at 364,369
# search start at 910,218
# search start at 173,161
# search start at 545,195
# search start at 75,273
# search start at 1162,155
# search start at 747,311
# search start at 51,4
# search start at 269,57
# search start at 1109,326
# search start at 165,76
# search start at 93,146
# search start at 839,107
# search start at 670,23
# search start at 499,87
# search start at 205,116
# search start at 54,368
# search start at 274,324
# search start at 294,251
# search start at 651,268
# search start at 718,239
# search start at 444,391
# search start at 683,205
# search start at 409,299
# search start at 1139,265
# search start at 518,103
# search start at 1000,109
# search start at 1226,203
# search start at 599,110
# search start at 895,103
# search start at 358,196
# search start at 2,282
# search start at 1077,157
# search start at 284,72
# search start at 1176,11
# search start at 589,350
# search start at 354,154
# search start at 1222,357
# search start at 520,328
# search start at 701,292
# search start at 545,396
# search start at 81,205
# search start at 489,84
# search start at 907,293
# search start at 1230,154
# search start at 264,72
# search start at 763,97
# search start at 849,327
# search start at 881,84
# search start at 410,17
# search start at 43,393
# search start at 946,250
# search start at 684,296
# search start at 343,14
# search start at 1190,334
# search start at 485,184
# search start at 778,84
# search start at 433,150
# search start at 522,165
# search start at 787,134
# search start at 201,116
# search start at 908,237
# search start at 1215,164
# search start at 331,359
# search start at 89,215
# search start at 1207,275
# search start at 522,282
# search start at 846,331
# search start at 554,275
# search start at 126,189
# search start at 171,80
# search start at 818,93
# search start at 867,347
# search start at 149,50
# search start at 808,206
# search start at 397,273
# search start at 176,214
# search start at 513,159
# search start at 687,284
# search start at 225,352
# search start at 354,187
# search start at 519,58
# search start at 892,351
# search start at 732,376
# search start at 727,357
# search start at 201,64
# search start at 182,340
# search start at 934,321
# search start at 788,128
# search start at 593,343
# search start at 1020,28
# search start at 354,172
# search start at 810,77
# search start at 915,251
# search start at 21,41
# search start at 755,13
# search start at 906,159
# search start at 624,165
# search start at 944,50
# search start at 12,400
# search start at 1035,373
# search start at 4,185
# search start at 884,125
# search start at 610,394
# search start at 98,287
# search start at 1222,350
# search start at 660,189
# search start at 377,30
# search start at 895,357
# search start at 3,168
# search start at 826,195
# search start at 162,47
# search start at 425,370
# search start at 930,198
# search start at 224,171
# search start at 981,111
# search start at 1197,151
# search start at 1149,50
# search start at 663,130
# search start at 1093,112
# search start at 1229,373
# search start at 858,210
# search start at 555,292
# search start at 1026,81
# search start at 245,355
# search start at 8,234
# search start at 1090,68
# search start at 330,92
# search start at 119,21
# search start at 1127,114
# search start at 76,234
# search start at 932,287
# search start at 624,139
# search start at 1012,132
# search start at 1157,181
# search start at 249,396
# search start at 806,148
# search start at 143,6
# search start at 182,257
# search start at 771,278
# search start at 939,324
# search start at 954,349
# search start at 386,325
# search start at 898,393
# search start at 706,314
# search start at 48,350
# search start at 1190,21
# search start at 707,160
# search start at 742,52
# search start at 568,338
# search start at 1115,68
# search start at 1206,255
# search start at 921,166
# search start at 292,315
# search start at 291,116
# search start at 719,135
# search start at 591,31
# search start at 300,398
# search start at 157,363
# search start at 281,219
# search start at 882,9
# search start at 947,366
# search start at 741,164
# search start at 900,382
# search start at 317,66
# search start at 235,136
# search start at 528,30
# search start at 684,128
# search start at 323,315
# search start at 1177,277
# search start at 54,153
# search start at 375,184
# search start at 335,50
# search start at 713,313
# search start at 271,19
# search start at 186,128
# search start at 215,119
# search start at 145,74
# search start at 1036,116
# search start at 630,52
# search start at 1224,16
# search start at 325,154
# search start at 1001,318
# search start at 212,222
# search start at 935,395
# search start at 203,104
# search start at 825,281
# search start at 1102,364
# search start at 652,229
# search start at 162,213
# search start at 1072,109
# search start at 86,360
# search start at 1047,193
# search start at 261,368
# search start at 1083,238
# search start at 878,302
# search start at 182,87
# search start at 1054,393
# search start at 4,399
# search start at 152,96
# search start at 763,326
# search start at 446,313
# search start at 1207,299
# search start at 655,236
# search start at 309,221
# search start at 541,251
# search start at 573,279
# search start at 1060,164
# search start at 693,195
# search start at 1081,226
# search start at 773,279
# search start at 60,127
# search start at 645,205
# search start at 729,169
# search start at 804,367
# search start at 1115,90
# search start at 672,364
# search start at 122,315
# search start at 183,266
# search start at 489,133
# search start at 754,124
# search start at 1168,162
# search start at 152,226
# search start at 952,105
# search start at 720,76
# search start at 730,97
# search start at 461,103
# search start at 910,43
# search start at 1166,170
# search start at 418,344
# search start at 563,284
# search start at 1152,71
# search start at 547,324
# search start at 357,22
# search start at 161,298
# search start at 210,165
# search start at 775,94
# search start at 1026,261
# search start at 1155,204
# search start at 318,42
# search start at 713,359
# search start at 1032,94
# search start at 862,316
# search start at 1226,274
# search start at 1061,196
# search start at 625,21
# search start at 1190,374
# search start at 1197,364
# search start at 450,9
# search start at 137,310
# search start at 1070,237
# search start at 942,162
# search start at 775,153
# search start at 910,109
# search start at 1059,5
# search start at 143,332
# search start at 243,285
# search start at 993,111
# search start at 160,62
# search start at 446,152
# search start at 36,365
# search start at 330,116
# search start at 826,326
# search start at 1005,61
# search start at 910,68
# search start at 1009,373
# search start at 12,44
# search start at 1053,75
# search start at 115,7
# search start at 1135,229
# search start at 834,334
# search start at 1083,155
# search start at 748,177
# search start at 997,87
# search start at 138,9
# search start at 440,127
# search start at 283,244
# search start at 444,289
# search start at 552,208
# search start at 265,220
# search start at 368,28
# search start at 418,81
# search start at 772,197
# search start at 304,227
# search start at 613,317
# search start at 504,117
# search start at 866,135
# search start at 1126,323
# search start at 681,203
# search start at 1079,70
# search start at 241,169
# search start at 1167,399
# search start at 697,244
# search start at 210,238
# search start at 972,212
# search start at 206,88
# search start at 199,296
# search start at 1099,363
# search start at 299,349
# search start at 335,389
# search start at 1221,297
# search start at 219,48
# search start at 183,322
# search start at 1179,216
# search start at 1141,8
# search start at 972,183
# search start at 208,369
# search start at 205,51
# search start at 14,172
# search start at 422,176
# search start at 504,211
# search start at 31,393
# search start at 607,186
# search start at 554,239
# search start at 98,171
# search start at 337,19
# search start at 140,312
# search start at 599,219
# search start at 1123,106
# search start at 345,109
# search start at 467,218
# search start at 509,52
# search start at 209,390
# search start at 959,53
# search start at 786,136
# search start at 479,38
# search start at 696,74
# search start at 781,97
# search start at 328,167
# search start at 669,262
# search start at 239,119
# search start at 1007,116
# search start at 670,23
# search start at 462,309
# search start at 474,245
# search start at 217,162
# search start at 990,230
# search start at 1129,394
# search start at 1084,329
# search start at 47,321
# search start at 937,354
# search start at 763,16
# search start at 1122,180
# search start at 805,260
# search start at 53,228
# search start at 1099,75
# search start at 1060,31
# search start at 536,234
# search start at 570,117
# search start at 735,45
# search start at 619,56
# search start at 107,219
# search start at 952,331
# search start at 404,273
# search start at 134,327
# search start at 504,9
# search start at 422,220
# search start at 1051,244
# search start at 510,221
# search start at 1104,321
# search start at 479,367
# search start at 23,181
# search start at 443,395
# search start at 892,204
# search start at 193,27
# search start at 1083,287
# search start at 939,348
# search start at 406,231
# search start at 474,290
# search start at 1071,398
# search start at 683,390
# search start at 49,96
# search start at 150,136
# search start at 1203,92
# search start at 157,380
# search start at 957,192
# search start at 629,14
# search start at 805,167
# search start at 945,66
# search start at 1069,188
# search start at 104,294
# search start at 871,362
# search start at 204,174
# search start at 732,22
# search start at 1022,131
# search start at 122,326
# search start at 704,153
# search start at 1153,361
# search start at 1120,23
# search start at 167,388
# search start at 248,135
# search start at 1147,205
# search start at 667,22
# search start at 700,245
# search start at 706,115
# search start at 288,365
# search start at 509,391
# search start at 1219,119
# search start at 1073,243
# search start at 1055,170
# search start at 203,39
# search start at 852,58
# search start at 1091,187
# search start at 55,242
# search start at 606,49
# search start at 696,84
# search start at 25,22
# search start at 734,365
# search start at 218,379
# search start at 443,239
# search start at 924,207
# search start at 786,132
# search start at 1025,326
# search start at 768,251
# search start at 4,340
# search start at 11,67
# search start at 915,83
# search start at 404,171
# search start at 793,83
# search start at 152,109
# search start at 735,319
# search start at 1195,67
# search start at 780,33
# search start at 105,139
# search start at 453,84
# search start at 846,271
# search start at 673,290
# search start at 508,46
# search start at 65,51
# search start at 772,97
# search start at 77,326
# search start at 137,110
# search start at 1153,53
# search start at 1207,171
# search start at 461,226
# search start at 663,85
# search start at 869,25
# search start at 572,197
# search start at 797,75
# search start at 766,148
# search start at 726,54
# search start at 1073,139
# search start at 207,332
# search start at 690,353
# search start at 456,156
# search start at 935,6
# search start at 655,17
# search start at 470,236
# search start at 344,388
# search start at 614,146
# search start at 222,9
# search start at 491,45
# search start at 682,389
# search start at 400,47
# search start at 691,297
# search start at 220,3
# search start at 656,170
# search start at 1033,174
# search start at 96,378
# search start at 42,296
# search start at 1096,288
# search start at 310,101
# search start at 861,149
# search start at 59,177
# search start at 582,210
# search start at 417,106
# search start at 37,15
# search start at 1117,232
# search start at 1180,20
# search start at 382,362
# search start at 7,97
# search start at 213,345
# search start at 967,395
# search start at 173,57
# search start at 416,395
# search start at 584,358
# search start at 108,338
# search start at 1069,399
# search start at 939,75
# search start at 454,251
# search start at 745,156
# search start at 3,87
# search start at 67,376
# search start at 476,150
# search start at 70,191
# search start at 156,307
# search start at 378,83
# search start at 587,277
# search start at 382,210
# search start at 1122,52
# search start at 1215,230
# search start at 1103,126
# search start at 365,112
# search start at 1002,307
# search start at 542,327
# search start at 177,250
# search start at 487,221
# search start at 1033,248
# search start at 580,47
# search start at 328,243
# search start at 152,27
# search start at 478,22
# search start at 1152,167
# search start at 920,271
# search start at 304,256
# search start at 313,136
# search start at 54,230
# search start at 1202,37
# search start at 939,170
# search start at 719,111
# search start at 155,60
# search start at 1228,39
# search start at 787,96
# search start at 1048,220
# search start at 1152,193
# search start at 533,199
# search start at 280,385
# search start at 233,185
# search start at 849,245
# search start at 444,0
# search start at 252,316
# search start at 792,237
# search start at 642,100
# search start at 944,309
# search start at 675,108
# search start at 838,31
# search start at 477,359
# search start at 105,152
# search start at 573,120
# search start at 218,117
# search start at 836,41
# search start at 160,107
# search start at 671,224
# search start at 1100,20
# search start at 827,62
# search start at 437,374
# search start at 676,86
# search start at 1173,25
# search start at 136,148
# search start at 1093,175
# search start at 65,131
# search start at 816,183
# search start at 783,59
# search start at 80,65
# search start at 1181,361
# search start at 218,250
# search start at 93,57
# search start at 133,159
# search start at 46,227
# search start at 605,132
# search start at 380,346
# search start at 283,285
# search start at 546,263
# search start at 366,107
# search start at 45,162
# search start at 898,73
# search start at 770,334
# search start at 1142,177
# search start at 1205,103
# search start at 1212,255
# search start at 787,35
# search start at 897,152
# search start at 1191,356
# search start at 44,230
# search start at 1019,308
# search start at 978,93
# search start at 728,251
# search start at 901,255
# search start at 898,276
# search start at 455,312
# search start at 532,381
# search start at 1108,199
# search start at 122,104
# search start at 749,88
# search start at 1118,395
# search start at 853,324
# search start at 44,222
# search start at 800,264
# search start at 352,84
# search start at 502,23
# search start at 1121,269
# search start at 344,251
# search start at 61,177
# search start at 136,191
# search start at 602,388
# search start at 437,334
# search start at 329,109
# search start at 170,76
# search start at 396,21
# search start at 440,344
# search start at 368,1
# search start at 568,95
# search start at 740,65
# search start at 1162,145
# search start at 21,117
# search start at 283,398
# search start at 38,217
# search start at 1170,243
# search start at 1091,148
# search start at 256,184
# search start at 1120,34
# search start at 414,269
# search start at 1019,116
# search start at 586,215
# search start at 548,34
# search start at 21,165
# search start at 1056,6
# search start at 978,104
# search start at 260,52
# search start at 400,118
# search start at 882,392
# search start at 447,94
# search start at 1218,216
# search start at 55,59
# search start at 841,118
# search start at 140,50
# search start at 588,199
# search start at 397,383
# search start at 685,1
# search start at 1124,136
# search start at 492,377
# search start at 382,198
# search start at 39,278
# search start at 530,279
# search start at 987,226
# search start at 395,389
# search start at 1094,133
# search start at 110,39
# search start at 824,216
# search start at 610,20
# search start at 81,322
# search start at 1194,248
# search start at 892,192
# search start at 0,385
# search start at 906,186
# search start at 176,120
# search start at 567,138
# search start at 436,379
# search start at 835,69
# search start at 383,226
# search start at 703,214
# search start at 538,11
# search start at 43,172
# search start at 1177,231
# search start at 793,17
# search start at 1046,42
# search start at 216,191
# search start at 565,31
# search start at 922,196
# search start at 152,249
# search start at 636,132
# search start at 278,322
# search start at 1218,112
# search start at 1171,361
# search start at 171,322
# search start at 154,387
# search start at 1153,137
# search start at 920,215
# search start at 186,83
# search start at 1006,388
# search start at 420,70
# search start at 120,370
# search start at 943,128
# search start at 491,223
# search start at 747,260
# search start at 806,330
# search start at 314,253
# search start at 760,14
# search start at 478,65
# search start at 457,203
# search start at 282,17
# search start at 977,332
# search start at 62,270
# search start at 664,392
# search start at 138,375
# search start at 286,95
# search start at 991,274
# search start at 376,244
# search start at 406,158
# search start at 469,278
# search start at 343,73
# search start at 102,232
# search start at 186,396
# search start at 275,12
# search start at 1015,192
# search start at 51,296
# search start at 759,343
# search start at 791,299
# search start at 188,194
# search start at 313,379
# search start at 1006,113
# search start at 940,5
# search start at 70,361
# search start at 1133,188
# search start at 395,42
# search start at 1093,84
# search start at 916,260
# search start at 676,161
# search start at 615,387
# search start at 236,250
# search start at 950,394
# search start at 816,209
# search start at 399,77
# search start at 547,19
# search start at 742,89
# search start at 162,117
# search start at 1201,27
# search start at 1024,32
# search start at 394,246
# search start at 1097,38
# search start at 444,19
# search start at 206,369
# search start at 54,268
# search start at 7,344
# search start at 320,272
# search start at 995,115
# search start at 539,266
# search start at 915,250
# search start at 95,159
# search start at 42,311
# search start at 1090,90
# search start at 1162,338
# search start at 891,78
# search start at 275,392
# search start at 998,146
# search start at 1090,281
# search start at 673,233
# search start at 874,125
# search start at 1208,266
# search start at 374,310
# search start at 434,164
# search start at 608,2
# search start at 186,365
# search start at 973,260
# search start at 235,340
# search start at 1003,3
# search start at 1054,40
# search start at 1119,77
# search start at 571,394
# search start at 481,340
# search start at 738,35
# search start at 1160,277
# search start at 962,97
# search start at 321,383
# search start at 53,179
# search start at 348,370
# search start at 762,207
# search start at 3,78
# search start at 1016,391
# search start at 817,395
# search start at 428,281
# search start at 52,398
# search start at 428,133
# search start at 226,98
# search start at 784,57
# search start at 204,350
# search start at 693,374
# search start at 693,121
# search start at 387,106
# search start at 673,272
# search start at 290,307
# search start at 68,168
# search start at 1053,320
# search start at 1035,304
# search start at 9,215
# search start at 80,374
# search start at 544,259
# search start at 591,396
# search start at 560,292
# search start at 1166,150
# search start at 487,367
# search start at 694,327
# search start at 542,230
# search start at 847,230
# search start at 831,43
# search start at 385,139
# search start at 573,354
# search start at 815,53
# search start at 499,249
# search start at 269,201
# search start at 175,352
# search start at 1151,203
# search start at 791,46
# search start at 77,241
# search start at 688,189
# search start at 739,112
# search start at 1096,178
# search start at 2,257
# search start at 895,247
# search start at 253,340
# search start at 207,370
# search start at 620,0
# search start at 1171,378
# search start at 1190,190
# search start at 257,371
# search start at 499,134
# search start at 350,300
# search start at 567,185
# search start at 454,76
# search start at 77,33
# search start at 382,265
# search start at 1026,290
# search start at 229,317
# search start at 581,110
# search start at 156,28
# search start at 774,275
# search start at 159,77
# search start at 519,229
# search start at 199,248
# search start at 18,294
# search start at 1011,315
# search start at 546,190
# search start at 185,389
# search start at 1142,192
# search start at 643,156
# search start at 558,375
# search start at 628,379
# search start at 1018,96
# search start at 97,386
# search start at 810,229
# search start at 643,262
# search start at 964,397
# search start at 1053,372
# search start at 1159,20
# search start at 1040,95
# search start at 91,297
# search start at 845,8
# search start at 913,116
# search start at 1148,122
# search start at 401,218
# search start at 81,243
# search start at 120,295
# search start at 1182,241
# search start at 82,278
# search start at 481,119
# search start at 578,133
# search start at 684,378
# search start at 162,98
# search start at 158,56
# search start at 877,313
# search start at 912,374
# search start at 127,283
# search start at 885,315
# search start at 311,160
# search start at 733,205
# search start at 111,183
# search start at 896,298
# search start at 941,95
# search start at 568,311
# search start at 383,46
# search start at 176,5
# search start at 1047,266
# search start at 413,295
# search start at 719,58
# search start at 544,53
# search start at 981,33
# search start at 396,334
# search start at 186,191
# search start at 390,213
# search start at 101,125
# search start at 693,0
# search start at 550,228
# search start at 925,165
# search start at 106,202
# search start at 134,38
# search start at 202,7
# search start at 195,384
# search start at 22,223
# search start at 190,152
# search start at 867,76
# search start at 481,229
# search start at 91,299
# search start at 505,154
# search start at 529,20
# search start at 520,363
# search start at 944,15
# search start at 815,24
# search start at 62,184
# search start at 781,107
# search start at 326,61
# search start at 102,13
# search start at 545,112
# search start at 919,28
# search start at 426,192
# search start at 1076,30
# search start at 476,375
# search start at 403,283
# search start at 1095,379
# search start at 1022,43
# search start at 406,287
# search start at 726,26
# search start at 289,111
# search start at 288,151
# search start at 897,195
# search start at 859,347
# search start at 10,198
# search start at 542,283
# search start at 901,147
# search start at 1213,270
# search start at 276,238
# search start at 666,330
# search start at 245,12
# search start at 1137,347
# search start at 355,190
# search start at 390,200
# search start at 333,288
# search start at 143,115
# search start at 1030,235
# search start at 198,388
# search start at 418,107
# search start at 842,34
# search start at 915,391
# search start at 551,348
# search start at 325,396
# search start at 856,197
# search start at 149,229
# search start at 982,7
# search start at 818,61
# search start at 76,279
# search start at 356,5
# search start at 869,243
# search start at 537,348
# search start at 140,383
# search start at 561,25
# search start at 1031,277
# search start at 132,174
# search start at 163,221
# search start at 853,296
# search start at 759,367
# search start at 515,182
# search start at 602,78
# search start at 1165,302
# search start at 930,343
# search start at 86,211
# search start at 597,90
# search start at 871,135
# search start at 1228,335
# search start at 170,118
# search start at 945,12
# search start at 434,43
# search start at 1106,201
# search start at 740,214
# search start at 822,352
# search start at 520,275
# search start at 43,34
# search start at 1195,254
# search start at 254,327
# search start at 411,289
# search start at 503,74
# search start at 419,379
# search start at 26,80
# search start at 751,362
# search start at 76,281
# search start at 971,335
# search start at 1,354
# search start at 662,369
# search start at 883,308
# search start at 528,278
# search start at 282,375
# search start at 378,388
# search start at 650,289
# search start at 694,76
# search start at 845,393
# search start at 470,194
# search start at 974,327
# search start at 4,241
# search start at 979,0
# search start at 1178,375
# search start at 950,67
# search start at 801,397
# search start at 535,386
# search start at 712,59
# search start at 811,289
# search start at 140,309
# search start at 265,347
# search start at 1184,367
# search start at 1161,99
# search start at 974,47
# search start at 453,251
# search start at 827,257
# search start at 753,58
# search start at 987,203
# search start at 808,232
# search start at 253,54
# search start at 1213,300
# search start at 930,52
# search start at 833,288
# search start at 1083,10
# search start at 320,249
# search start at 1154,233
# search start at 285,296
# search start at 427,307
# search start at 772,394
# search start at 781,342
# search start at 552,41
# search start at 985,319
# search start at 657,2
# search start at 239,90
# search start at 618,357
# search start at 883,38
# search start at 1129,330
# search start at 456,118
# search start at 999,218
# search start at 812,102
# search start at 840,267
# search start at 187,145
# search start at 780,87
# search start at 939,287
# search start at 753,94
# search start at 731,18
# search start at 398,122
# search start at 1137,377
# search start at 305,9
# search start at 590,219
# search start at 681,161
# search start at 311,9
# search start at 351,11
# search start at 506,29
# search start at 401,65
# search start at 758,57
# search start at 976,34
# search start at 61,163
# search start at 827,357
# search start at 188,91
# search start at 229,5
# search start at 767,221
# search start at 1208,198
# search start at 728,162
# search start at 537,255
# search start at 143,218
# search start at 452,395
# search start at 759,56
# search start at 539,15
# search start at 950,242
# search start at 1121,341
# search start at 1000,248
# search start at 594,51
# search start at 1221,358
# search start at 154,26
# search start at 802,384
# search start at 788,302
# search start at 1157,279
# search start at 1152,13
# search start at 1075,316
# search start at 360,58
# search start at 874,386
# search start at 966,251
# search start at 724,141
# search start at 1227,60
# search start at 7,219
# search start at 502,55
# search start at 1071,127
# search start at 995,103
# search start at 148,15
# search start at 851,198
# search start at 683,146
# search start at 131,222
# search start at 1059,277
# search start at 730,278
# search start at 804,257
# search start at 409,148
# search start at 241,395
# search start at 425,365
# search start at 680,38
# search start at 238,173
# search start at 148,291
# search start at 822,293
# search start at 461,130
# search start at 680,92
# search start at 241,386
# search start at 721,276
# search start at 127,341
# search start at 505,317
# search start at 783,297
# search start at 751,325
# search start at 573,273
# search start at 1004,99
# search start at 1004,24
# search start at 372,3
# search start at 909,318
# search start at 938,21
# search start at 369,200
# search start at 523,180
# search start at 117,233
# search start at 662,154
# search start at 495,256
# search start at 106,82
# search start at 688,359
# search start at 571,390
# search start at 701,290
# search start at 1011,22
# search start at 734,81
# search start at 895,327
# search start at 1162,379
# search start at 1098,331
# search start at 222,153
# search start at 466,216
# search start at 0,178
# search start at 455,86
# search start at 1063,385
# search start at 1218,31
# search start at 263,80
# search start at 279,179
# search start at 328,236
# search start at 134,133
# search start at 978,115
# search start at 864,181
# search start at 524,267
# search start at 863,237
# search start at 252,128
# search start at 255,398
# search start at 932,270
# search start at 132,135
# search start at 855,44
# search start at 1175,316
# search start at 388,184
# search start at 590,275
# search start at 261,336
# search start at 121,267
# search start at 1,207
# search start at 1005,64
# search start at 837,13
# search start at 570,372
# search start at 930,292
# search start at 1007,215
# search start at 1096,352
# search start at 1024,80
# search start at 365,202
# search start at 550,391
# search start at 649,23
# search start at 1035,335
# search start at 927,98
# search start at 118,136
# search start at 669,183
# search start at 313,346
# search start at 123,65
# search start at 565,110
# search start at 153,233
# search start at 31,21
# search start at 604,357
# search start at 915,130
# search start at 371,335
# search start at 1003,306
# search start at 884,211
# search start at 442,324
# search start at 852,142
# search start at 824,291
# search start at 151,177
# search start at 452,174
# search start at 99,251
# search start at 1166,244
# search start at 959,336
# search start at 21,313
# search start at 892,228
# search start at 506,36
# search start at 562,53
# search start at 153,320
# search start at 753,137
# search start at 179,214
# search start at 215,64
# search start at 1047,166
# search start at 366,272
# search start at 1207,255
# search start at 978,69
# search start at 606,272
# search start at 520,271
# search start at 1130,355
# search start at 1090,218
# search start at 713,122
# search start at 1096,65
# search start at 980,182
# search start at 183,304
# search start at 741,245
# search start at 317,234
# search start at 289,246
# search start at 330,218
# search start at 340,254
# search start at 890,37
# search start at 611,35
# search start at 796,21
# search start at 1171,269
# search start at 1028,241
# search start at 795,3
# search start at 933,357
# search start at 181,141
# search start at 59,355
# search start at 213,354
# ...
# search start at 741,285
# search start at 409,72
# search start at 1228,30
# search start at 1176,384
# search start at 424,305
# search start at 415,164
# search start at 892,228
# search start at 204,71
# search start at 970,280
# search start at 1005,62
# search start at 164,108
# search start at 751,88
# search start at 96,292
# search start at 285,35
# search start at 799,32
# search start at 625,163
# search start at 88,34
# search start at 163,202
# search start at 486,157
# search start at 1042,24
# search start at 650,291
# search start at 899,169
# search start at 439,343
# search start at 721,367
# search start at 897,294
# search start at 508,309
# search start at 758,94
# search start at 837,307
# search start at 142,140
# search start at 1178,82
# search start at 262,208
# search start at 63,362
# search start at 579,330
# search start at 842,258
# search start at 740,139
# search start at 748,118
# search start at 856,240
# search start at 40,104
# search start at 136,233
# search start at 531,118
# search start at 78,228
# search start at 548,46
# search start at 480,160
# search start at 785,265
# search start at 40,195
# search start at 803,373
# search start at 1042,90
# search start at 920,163
# search start at 680,185
# search start at 675,384
# search start at 551,26
# search start at 186,91
# search start at 821,25
# search start at 178,303
# search start at 1226,210
# search start at 65,249
# search start at 889,34
# search start at 122,44
# search start at 1101,141
# search start at 721,202
# search start at 1109,304
# search start at 143,233
# search start at 523,304
# search start at 205,191
# search start at 789,357
# search start at 165,44
# search start at 1096,252
# search start at 1010,41
# search start at 915,219
# search start at 16,275
# search start at 1054,214
# search start at 181,337
# search start at 164,207
# search start at 14,349
# search start at 823,157
# search start at 504,15
# search start at 991,73
# search start at 365,349
# search start at 1193,375
# search start at 509,3
# search start at 411,110
# search start at 1224,123
# search start at 114,107
# search start at 467,182
# search start at 321,333
# search start at 431,324
# search start at 931,22
# search start at 1170,362
# search start at 454,116
# search start at 251,286
# search start at 717,124
# search start at 588,200
# search start at 145,68
# search start at 983,250
# search start at 349,287
# search start at 1005,139
# search start at 1141,148
# search start at 452,335
# search start at 167,278
# search start at 696,299
# search start at 97,372
# search start at 527,14
# search start at 636,324
# search start at 1129,279
# search start at 451,121
# search start at 652,10
# search start at 654,19
# search start at 7,305
# search start at 871,164
# search start at 702,70
# search start at 901,288
# search start at 422,259
# search start at 1008,397
# search start at 77,54
# search start at 48,371
# search start at 878,26
# search start at 419,41
# search start at 1180,366
# search start at 1016,350
# search start at 520,295
# search start at 301,21
# search start at 667,130
# search start at 58,186
# search start at 238,266
# search start at 829,6
# search start at 294,12
# search start at 877,142
# search start at 1142,140
# search start at 983,85
# search start at 350,288
# search start at 764,115
# search start at 6,121
# search start at 437,179
# search start at 240,261
# search start at 977,239
# search start at 844,346
# search start at 632,279
# search start at 991,298
# search start at 121,76
# search start at 740,259
# search start at 911,15
# search start at 71,88
# search start at 765,267
# search start at 719,77
# search start at 829,244
# search start at 326,28
# search start at 10,46
# search start at 694,124
# search start at 411,290
# search start at 1202,38
# search start at 749,146
# search start at 250,217
# search start at 557,242
# search start at 286,373
# search start at 168,84
# search start at 695,139
# search start at 259,312
# search start at 350,226
# search start at 1129,192
# search start at 792,106
# search start at 661,102
# search start at 817,278
# search start at 191,145
# search start at 427,145
# search start at 1084,164
# search start at 722,382
# search start at 1022,236
# search start at 1147,93
# search start at 734,85
# search start at 344,116
# search start at 961,167
# search start at 1201,261
# search start at 722,371
# search start at 1037,209
# search start at 305,131
# search start at 557,367
# search start at 717,367
# search start at 721,185
# search start at 1115,280
# search start at 532,203
# search start at 58,310
# search start at 889,63
# search start at 444,232
# search start at 753,188
# search start at 6,137
# search start at 82,210
# search start at 772,157
# search start at 1186,265
# search start at 1066,51
# search start at 166,226
# search start at 857,145
# search start at 887,298
# search start at 864,326
# search start at 999,291
# search start at 453,71
# search start at 41,131
# search start at 165,242
# search start at 209,296
# search start at 1203,283
# search start at 712,156
# search start at 812,278
# search start at 438,126
# search start at 1141,346
# search start at 545,38
# search start at 162,358
# search start at 750,209
# search start at 474,262
# search start at 1184,293
# search start at 323,347
# search start at 136,165
# search start at 722,4
# search start at 621,358
# search start at 533,389
# search start at 995,319
# search start at 995,74
# search start at 16,122
# search start at 780,123
# search start at 388,320
# search start at 604,176
# search start at 1116,158
# search start at 782,154
# search start at 716,323
# search start at 36,286
# search start at 944,145
# search start at 214,105
# search start at 904,99
# search start at 15,341
# search start at 188,211
# search start at 111,157
# search start at 967,158
# search start at 226,172
# search start at 485,365
# search start at 629,287
# search start at 83,123
# search start at 48,122
# search start at 847,340
# search start at 1078,249
# search start at 223,71
# search start at 1209,224
# search start at 962,345
# search start at 471,127
# search start at 170,299
# search start at 716,304
# search start at 408,286
# search start at 905,126
# search start at 459,156
# search start at 1024,93
# search start at 676,192
# search start at 402,233
# search start at 1121,309
# search start at 918,247
# search start at 502,142
# search start at 557,233
# search start at 246,273
# search start at 554,25
# search start at 642,187
# search start at 858,36
# search start at 198,33
# search start at 19,367
# search start at 578,11
# search start at 151,55
# search start at 1150,92
# search start at 224,276
# search start at 544,103
# search start at 857,5
# search start at 254,170
# search start at 188,0
# search start at 132,371
# search start at 714,400
# search start at 1085,236
# search start at 691,299
# search start at 514,49
# search start at 1127,60
# search start at 936,380
# search start at 896,88
# search start at 987,388
# search start at 173,235
# search start at 955,397
# search start at 876,111
# search start at 413,84
# search start at 722,284
# search start at 604,314
# search start at 619,102
# search start at 845,44
# search start at 538,320
# search start at 1047,286
# search start at 958,309
# search start at 720,230
# search start at 212,263
# search start at 622,354
# search start at 716,17
# search start at 645,291
# search start at 1060,378
# search start at 270,177
# search start at 769,3
# search start at 525,356
# search start at 54,359
# search start at 1090,383
# search start at 618,93
# search start at 658,386
# search start at 383,46
# search start at 181,171
# search start at 192,345
# search start at 886,306
# search start at 426,43
# search start at 117,119
# search start at 1072,108
# search start at 680,123
# search start at 645,324
# search start at 365,382
# search start at 827,279
# search start at 490,378
# search start at 114,163
# search start at 168,315
# search start at 210,353
# search start at 787,160
# search start at 326,244
# search start at 841,16
# search start at 1,199
# search start at 985,55
# search start at 492,356
# search start at 79,386
# search start at 983,108
# search start at 623,71
# search start at 1048,299
# search start at 1086,149
# search start at 506,325
# search start at 313,368
# search start at 1012,50
# search start at 45,204
# search start at 749,87
# search start at 563,285
# search start at 55,145
# search start at 715,26
# search start at 1114,57
# search start at 34,108
# search start at 765,377
# search start at 494,197
# search start at 185,289
# search start at 984,172
# search start at 769,83
# search start at 1110,117
# search start at 754,351
# search start at 891,37
# search start at 4,89
# search start at 936,334
# search start at 778,173
# search start at 75,244
# search start at 750,129
# search start at 620,85
# search start at 759,386
# search start at 606,130
# search start at 911,350
# search start at 627,93
# search start at 888,341
# search start at 75,380
# search start at 1136,331
# search start at 869,273
# search start at 167,144
# search start at 816,36
# search start at 109,304
# search start at 498,265
# search start at 81,348
# search start at 77,396
# search start at 243,335
# search start at 801,208
# search start at 753,376
# search start at 5,310
# search start at 337,322
# search start at 243,374
# search start at 718,357
# search start at 1209,192
# search start at 592,106
# search start at 674,385
# search start at 367,218
# search start at 1176,355
# search start at 471,383
# search start at 526,297
# search start at 837,212
# search start at 397,258
# search start at 516,112
# search start at 550,18
# search start at 413,375
# search start at 1083,9
# search start at 523,167
# search start at 1105,114
# search start at 462,380
# search start at 1188,353
# search start at 565,327
# search start at 535,30
# search start at 19,275
# search start at 287,263
# search start at 364,239
# search start at 533,10
# search start at 61,5
# search start at 102,292
# search start at 393,0
# search start at 726,42
# search start at 1030,273
# search start at 313,328
# search start at 142,289
# search start at 1037,9
# search start at 294,128
# search start at 817,88
# search start at 551,304
# search start at 589,230
# search start at 315,121
# search start at 930,270
# search start at 996,318
# search start at 389,78
# search start at 903,160
# search start at 13,245
# search start at 1205,235
# search start at 117,273
# search start at 76,331
# search start at 806,382
# search start at 800,328
# search start at 1020,377
# search start at 436,316
# search start at 618,198
# search start at 218,168
# search start at 410,98
# search start at 104,194
# search start at 297,124
# search start at 661,297
# search start at 235,39
# search start at 70,201
# search start at 131,0
# search start at 404,202
# search start at 541,26
# search start at 889,110
# search start at 455,3
# search start at 369,334
# search start at 744,257
# search start at 442,170
# search start at 374,227
# search start at 654,295
# search start at 756,324
# search start at 627,162
# search start at 142,186
# search start at 708,181
# search start at 1033,200
# search start at 630,269
# search start at 628,374
# search start at 305,235
# search start at 969,90
# search start at 321,113
# search start at 371,204
# search start at 350,367
# search start at 889,229
# search start at 120,136
# search start at 290,37
# search start at 269,93
# search start at 935,144
# search start at 77,341
# search start at 182,373
# search start at 1173,136
# search start at 749,308
# search start at 1038,139
# search start at 52,250
# search start at 881,373
# search start at 848,58
# search start at 603,153
# search start at 1008,357
# search start at 451,127
# search start at 728,239
# search start at 670,147
# search start at 135,281
# search start at 181,320
# search start at 247,237
# search start at 755,187
# search start at 474,211
# search start at 296,84
# search start at 872,4
# search start at 894,335
# search start at 1026,197
# search start at 990,9
# search start at 216,117
# search start at 1206,105
# search start at 595,177
# search start at 225,211
# search start at 19,104
# search start at 206,103
# search start at 792,86
# search start at 362,366
# search start at 980,191
# search start at 392,215
# search start at 1031,120
# search start at 577,19
# search start at 1068,217
# search start at 219,101
# search start at 36,82
# search start at 530,95
# search start at 65,81
# search start at 566,74
# search start at 138,3
# search start at 890,203
# search start at 1103,49
# search start at 915,29
# search start at 433,276
# search start at 261,143
# search start at 514,102
# search start at 181,203
# search start at 243,396
# search start at 719,28
# search start at 773,8
# search start at 664,241
# search start at 681,292
# search start at 219,270
# search start at 480,307
# search start at 522,269
# search start at 1052,370
# search start at 88,268
# search start at 186,131
# search start at 675,144
# search start at 410,158
# search start at 65,16
# search start at 996,330
# search start at 732,237
# search start at 1158,275
# search start at 969,295
# search start at 1051,6
# search start at 855,102
# search start at 148,345
# search start at 1011,57
# search start at 489,183
# search start at 113,323
# search start at 762,126
# search start at 1135,107
# search start at 631,141
# search start at 1044,89
# search start at 1191,232
# search start at 1059,248
# search start at 1161,134
# search start at 1174,375
# search start at 969,102
# search start at 1039,329
# search start at 264,43
# search start at 195,189
# search start at 559,80
# search start at 782,231
# search start at 1075,338
# search start at 315,362
# search start at 234,114
# search start at 745,248
# search start at 967,292
# search start at 707,389
# search start at 496,167
# search start at 177,97
# search start at 221,356
# search start at 1091,357
# search start at 470,163
# search start at 537,324
# search start at 408,202
# search start at 745,92
# search start at 874,233
# search start at 1028,257
# search start at 362,368
# search start at 733,210
# search start at 816,39
# search start at 1146,63
# search start at 226,172
# search start at 521,180
# search start at 1208,348
# search start at 681,263
# search start at 834,177
# search start at 832,331
# search start at 616,307
# search start at 428,258
# search start at 324,397
# search start at 151,117
# search start at 702,281
# search start at 172,126
# search start at 1140,138
# search start at 460,272
# search start at 289,153
# search start at 978,359
# search start at 1101,150
# search start at 808,393
# search start at 82,181
# search start at 172,46
# search start at 1058,389
# search start at 683,354
# search start at 891,68
# search start at 1178,242
# search start at 651,9
# search start at 835,245
# search start at 928,223
# search start at 421,136
# search start at 1020,72
# search start at 129,274
# search start at 1055,227
# search start at 290,157
# search start at 397,345
# search start at 258,134
# search start at 76,148
# search start at 1222,362
# search start at 495,349
# search start at 425,100
# search start at 655,335
# search start at 305,96
# search start at 591,400
# search start at 991,57
# search start at 501,208
# search start at 296,141
# search start at 757,195
# search start at 643,396
# search start at 1051,255
# search start at 310,43
# search start at 1230,62
# search start at 442,359
# search start at 200,117
# search start at 55,121
# search start at 1010,379
# search start at 474,294
# search start at 720,326
# search start at 44,268
# search start at 798,8
# search start at 683,226
# search start at 190,116
# search start at 510,90
# search start at 565,153
# search start at 480,63
# search start at 1119,389
# search start at 396,309
# search start at 800,225
# search start at 491,343
# search start at 427,261
# search start at 805,29
# search start at 682,185
# search start at 816,44
# search start at 1067,102
# search start at 493,217
# search start at 1095,302
# search start at 688,363
# search start at 765,85
# search start at 317,245
# search start at 1229,200
# search start at 333,282
# search start at 254,30
# search start at 922,54
# search start at 54,198
# search start at 1014,114
# search start at 1219,238
# search start at 1160,91
# search start at 1158,77
# search start at 1182,301
# search start at 1035,363
# search start at 1013,0
# search start at 465,274
# search start at 820,301
# search start at 315,359
# search start at 674,130
# search start at 699,47
# search start at 237,71
# search start at 703,195
# search start at 993,73
# search start at 821,285
# search start at 820,17
# search start at 144,205
# search start at 1050,189
# search start at 1190,99
# search start at 1144,178
# search start at 809,113
# search start at 656,278
# search start at 101,244
# search start at 1125,32
# search start at 155,202
# search start at 1162,390
# search start at 837,214
# search start at 906,156

# %%
t.tic()
intermidiate_index, intermidiate_paths = find_k_best(1)
t.toc()
# Out:
# search start at 1114,323
# search start at 742,332
# search start at 191,88
# search start at 539,64
# search start at 1103,131
# search start at 684,315
# search start at 775,358
# search start at 626,375
# search start at 996,205
# search start at 609,266
# search start at 599,105
# search start at 985,155
# search start at 429,376
# search start at 575,313
# search start at 295,153
# search start at 1118,20
# search start at 634,54
# search start at 638,29
# search start at 942,398
# search start at 116,254
# search start at 525,390
# search start at 540,335
# search start at 1194,238
# search start at 943,131
# search start at 860,389
# search start at 487,240
# search start at 264,302
# search start at 182,88
# search start at 192,308
# search start at 1090,87
# search start at 145,136
# search start at 826,174
# search start at 554,392
# search start at 1225,26
# search start at 364,234
# search start at 1085,23
# search start at 632,100
# search start at 10,40
# search start at 245,376
# search start at 762,264
# search start at 618,228
# search start at 1187,243
# search start at 547,395
# search start at 1206,323
# search start at 361,257
# search start at 1082,203
# search start at 1106,293
# search start at 880,247
# search start at 895,12
# search start at 743,114
# search start at 879,376
# search start at 851,171
# search start at 334,310
# search start at 597,372
# search start at 1129,44
# search start at 1052,253
# search start at 815,261
# search start at 35,226
# search start at 688,214
# search start at 378,52
# search start at 305,69
# search start at 488,64
# search start at 616,114
# search start at 691,390
# search start at 794,180
# search start at 1059,274
# search start at 240,236
# search start at 649,184
# search start at 990,379
# search start at 850,52
# search start at 626,283
# search start at 744,239
# search start at 250,264
# search start at 514,326
# search start at 245,395
# search start at 337,377
# search start at 868,150
# search start at 1088,123
# search start at 157,144
# search start at 1169,211
# search start at 994,179
# search start at 1062,264
# search start at 858,195
# search start at 668,73
# search start at 598,316
# search start at 199,71
# search start at 1215,289
# search start at 585,141
# search start at 58,366
# search start at 455,95
# search start at 745,154
# search start at 881,95
# search start at 528,355
# search start at 1132,311
# search start at 1032,6
# search start at 95,223
# search start at 771,36
# search start at 647,129
# search start at 357,331
# search start at 247,355
# search start at 809,396
# search start at 285,12
# search start at 697,297
# search start at 457,285
# search start at 1027,114
# search start at 421,243
# search start at 622,158
# search start at 535,332
# search start at 470,4
# search start at 169,55
# search start at 217,59
# search start at 534,211
# search start at 41,236
# search start at 1043,123
# search start at 699,220
# search start at 1104,337
# search start at 1024,18
# search start at 366,106
# search start at 446,7
# search start at 225,399
# search start at 384,25
# search start at 332,34
# search start at 55,295
# search start at 506,140
# search start at 1091,38
# search start at 649,130
# search start at 700,231
# search start at 169,283
# search start at 973,75
# search start at 265,175
# search start at 21,187
# search start at 518,91
# search start at 394,256
# search start at 1183,298
# search start at 296,232
# search start at 75,329
# search start at 834,362
# search start at 1098,47
# search start at 144,238
# search start at 451,65
# search start at 736,210
# search start at 344,237
# search start at 1211,7
# search start at 1089,260
# search start at 323,202
# search start at 706,349
# search start at 667,53
# search start at 605,352
# search start at 970,310
# search start at 785,345
# search start at 221,29
# search start at 10,390
# search start at 1132,106
# search start at 425,369
# search start at 1187,90
# search start at 2,360
# search start at 852,382
# search start at 146,72
# search start at 38,2
# search start at 784,220
# search start at 421,388
# search start at 145,268
# search start at 593,367
# search start at 514,250
# search start at 12,315
# search start at 514,172
# search start at 178,385
# search start at 431,277
# search start at 566,168
# search start at 522,186
# search start at 873,27
# search start at 816,296
# search start at 1022,18
# search start at 80,60
# search start at 595,255
# search start at 964,307
# search start at 356,23
# search start at 376,145
# search start at 30,361
# search start at 348,308
# search start at 814,291
# search start at 690,369
# search start at 950,364
# search start at 1120,128
# search start at 702,285
# search start at 1045,12
# search start at 419,247
# search start at 533,88
# search start at 37,6
# search start at 154,81
# search start at 1177,22
# search start at 369,105
# search start at 522,164
# search start at 504,63
# search start at 102,50
# search start at 877,256
# search start at 707,330
# search start at 125,203
# search start at 777,46
# search start at 106,214
# search start at 1228,58
# search start at 638,59
# search start at 647,270
# search start at 1117,335
# search start at 695,208
# search start at 1133,139
# search start at 450,19
# search start at 20,345
# search start at 41,281
# search start at 237,153
# search start at 99,1
# search start at 848,86
# search start at 484,389
# search start at 647,119
# search start at 708,259
# search start at 344,107
# search start at 368,30
# search start at 379,27
# search start at 112,305
# search start at 425,96
# search start at 1105,215
# search start at 404,376
# search start at 768,388
# search start at 1200,303
# search start at 852,84
# search start at 628,241
# search start at 1120,199
# search start at 654,18
# search start at 1160,222
# search start at 1105,311
# search start at 1156,221
# search start at 534,314
# search start at 867,199
# search start at 94,391
# search start at 621,218
# search start at 250,93
# search start at 258,315
# search start at 1040,115
# search start at 300,24
# search start at 678,142
# search start at 1133,219
# search start at 355,42
# search start at 865,210
# search start at 691,197
# search start at 983,245
# search start at 724,380
# search start at 1094,26
# search start at 357,30
# search start at 571,384
# search start at 689,118
# search start at 263,345
# search start at 185,213
# search start at 785,318
# search start at 825,125
# search start at 82,215
# search start at 473,176
# search start at 608,49
# search start at 382,222
# search start at 1110,244
# search start at 835,32
# search start at 754,263
# search start at 850,164
# search start at 1,84
# search start at 868,49
# search start at 160,203
# search start at 880,160
# search start at 693,171
# search start at 284,9
# search start at 441,215
# search start at 225,195
# search start at 623,400
# search start at 923,199
# search start at 306,331
# search start at 123,257
# search start at 1004,400
# search start at 785,145
# search start at 159,38
# search start at 816,182
# search start at 974,361
# search start at 368,345
# search start at 1122,109
# search start at 802,155
# search start at 363,38
# search start at 409,141
# search start at 398,252
# search start at 963,345
# search start at 324,285
# search start at 1079,325
# search start at 179,12
# search start at 360,70
# search start at 57,109
# search start at 1033,105
# search start at 126,253
# search start at 225,342
# search start at 108,210
# search start at 1023,18
# search start at 265,190
# search start at 1075,166
# search start at 468,69
# search start at 1158,122
# search start at 291,380
# search start at 871,300
# search start at 549,222
# search start at 1135,331
# search start at 358,270
# search start at 1012,211
# search start at 890,196
# search start at 193,121
# search start at 1169,148
# search start at 573,267
# search start at 712,375
# search start at 801,305
# search start at 738,365
# search start at 600,81
# search start at 280,124
# search start at 632,190
# search start at 263,145
# search start at 881,334
# search start at 106,305
# search start at 491,129
# search start at 162,314
# search start at 780,355
# search start at 825,47
# search start at 146,69
# search start at 172,346
# search start at 429,211
# search start at 363,133
# search start at 801,364
# search start at 133,392
# search start at 106,171
# search start at 760,396
# search start at 180,0
# search start at 593,316
# search start at 1225,341
# search start at 16,178
# search start at 113,244
# search start at 809,350
# search start at 622,255
# search start at 612,90
# search start at 979,119
# search start at 3,317
# search start at 905,338
# search start at 211,122
# search start at 709,110
# search start at 322,386
# search start at 854,212
# search start at 204,109
# search start at 562,269
# search start at 255,290
# search start at 971,396
# search start at 565,139
# search start at 900,174
# search start at 1171,94
# search start at 1085,333
# search start at 213,203
# search start at 500,28
# search start at 1004,222
# search start at 416,21
# search start at 469,351
# search start at 602,116
# search start at 251,166
# search start at 609,66
# search start at 663,54
# search start at 348,204
# search start at 994,372
# search start at 762,245
# search start at 331,112
# search start at 874,133
# search start at 617,198
# search start at 215,243
# search start at 1207,25
# search start at 134,36
# search start at 1028,69
# search start at 440,335
# search start at 112,190
# search start at 746,46

# %%
t.tic()
hard_index, hard_paths = find_k_best(2)
t.toc()
# Out:
# search start at 366,235
# search start at 781,231
# search start at 704,268
# search start at 827,9
# search start at 711,73
# search start at 448,156
# search start at 860,204
# search start at 491,397
# search start at 147,263
# search start at 1043,290
# search start at 648,170
# search start at 136,295
# search start at 870,175
# search start at 714,315
# search start at 262,389
# search start at 126,83
# search start at 1205,367
# search start at 495,226
# search start at 628,238
# search start at 1075,76
# search start at 582,274
# search start at 388,8
# search start at 1181,118
# search start at 1161,381
# search start at 3,86
# search start at 102,276
# search start at 677,74
# search start at 315,310
# search start at 762,65
# search start at 228,96
# search start at 1081,43
# search start at 395,179
# search start at 411,272
# search start at 1181,221
# search start at 1142,352
# search start at 1194,172
# search start at 970,165
# search start at 395,237
# search start at 858,369
# search start at 434,226
# search start at 964,371
# search start at 1025,103
# search start at 575,94
# search start at 933,190
# search start at 618,87
# search start at 337,317
# search start at 1206,142
# search start at 1115,276
# search start at 110,244
# search start at 697,264
# search start at 874,334
# search start at 513,139
# search start at 1152,379
# search start at 45,213
# search start at 846,91
# search start at 311,278
# search start at 446,270
# search start at 871,288
# search start at 159,73
# search start at 1117,164
# search start at 118,348
# search start at 520,224
# search start at 550,4
# search start at 896,38
# search start at 264,63
# search start at 1138,242
# search start at 567,172
# search start at 112,82
# search start at 1039,390
# search start at 177,350
# search start at 914,340
# search start at 140,170
# search start at 1204,362
# search start at 1175,44
# search start at 1090,301
# search start at 154,216
# search start at 499,153
# search start at 432,151
# search start at 524,27
# search start at 510,28
# search start at 168,152
# search start at 981,43
# search start at 360,174
# search start at 523,310
# search start at 1138,356
# search start at 831,131
# search start at 49,359
# search start at 1015,284
# search start at 1076,116
# search start at 1028,0
# search start at 726,177
# search start at 317,26
# search start at 297,125
# search start at 230,319
# search start at 654,67
# search start at 236,299
# search start at 446,313
# search start at 267,228
# search start at 1124,289
# search start at 511,194
# search start at 617,95
# search start at 1127,367
# search start at 663,255
# search start at 841,205
# search start at 1144,375
# search start at 305,389
# search start at 1073,91
# search start at 930,220
# search start at 434,147
# search start at 509,308
# search start at 936,360
# search start at 347,360
# search start at 793,109
# search start at 152,37
# search start at 39,199
# search start at 540,359
# search start at 674,291
# search start at 1197,182
# search start at 265,38
# search start at 938,248
# search start at 671,354
# search start at 860,132
# search start at 570,213
# search start at 690,165
# search start at 552,301
# search start at 495,79
# search start at 415,163
# search start at 505,176
# search start at 1177,285
# search start at 1201,306
# search start at 672,114
# search start at 900,253
# search start at 512,105
# search start at 1089,142
# search start at 661,183
# search start at 418,280
# search start at 718,380
# search start at 614,290
# search start at 93,337
# search start at 746,307
# search start at 1166,141
# search start at 505,103
# search start at 1035,123
# search start at 1214,399
# search start at 176,152
# search start at 121,319
# search start at 143,207
# search start at 52,52
# search start at 997,40
# search start at 269,229
# search start at 710,84
# search start at 1063,223
# search start at 849,379
# search start at 975,142
# search start at 1106,318
# search start at 1222,305
# search start at 17,32
# search start at 563,195
# search start at 543,78
# search start at 190,189
# search start at 537,75
# search start at 1167,354
# search start at 198,276
# search start at 1087,67
# search start at 1220,207
# search start at 1163,170
# search start at 712,47
# search start at 28,369
# search start at 49,275
# search start at 345,353
# search start at 622,180
# search start at 937,216
# search start at 1018,247
# search start at 504,121
# search start at 926,251
# search start at 939,66
# search start at 157,73
# search start at 243,224
# search start at 1029,190
# search start at 481,189
# search start at 913,325
# search start at 591,177
# search start at 664,124
# search start at 1040,287
# search start at 1173,162
# search start at 34,377
# search start at 437,379
# search start at 1013,214
# search start at 783,389
# search start at 801,248
# search start at 678,303
# search start at 476,59
# search start at 321,2
# search start at 310,10
# search start at 1109,269
# search start at 45,175
# search start at 757,297
# search start at 1144,200
# search start at 1198,38
# search start at 673,239
# search start at 311,173
# search start at 677,79
# search start at 591,170
# search start at 1181,342
# search start at 803,243
# search start at 986,116
# search start at 340,309
# search start at 727,271
# search start at 946,270
# search start at 1196,391
# search start at 447,280
# search start at 346,252
# search start at 306,243
# search start at 202,117
# search start at 240,138
# search start at 155,6
# search start at 754,257
# search start at 999,27
# search start at 899,189
# search start at 904,114
# search start at 635,52
# search start at 913,62
# search start at 616,228
# search start at 391,44
# search start at 456,229
# search start at 262,147
# search start at 300,325
# search start at 38,357
# search start at 163,96
# search start at 1089,349
# search start at 491,226
# search start at 725,70
# search start at 392,244
# search start at 1049,230
# search start at 1198,250
# search start at 1008,339
# search start at 773,167
# search start at 1099,183
# search start at 38,235
# search start at 504,68
# search start at 897,120
# search start at 538,55
# search start at 69,294
# search start at 21,121
# search start at 982,351
# search start at 442,213
# search start at 1066,103
# search start at 891,181
# search start at 503,153
# search start at 459,203
# search start at 466,76
# search start at 142,200
# search start at 615,69
# search start at 893,319
# search start at 151,54
# search start at 48,195
# search start at 655,277
# search start at 959,170
# search start at 860,53
# search start at 392,345
# search start at 90,227
# search start at 115,325
# search start at 289,105
# search start at 643,247
# search start at 251,40
# search start at 622,11
# search start at 268,123
# search start at 292,137
# search start at 68,21
# search start at 192,156
# search start at 437,33
# search start at 9,309
# search start at 218,241
# search start at 747,151
# search start at 192,138
# search start at 1213,232
# search start at 649,45
# search start at 451,117
# search start at 929,328
# search start at 1089,107
# search start at 709,265
# search start at 553,223
# search start at 130,175
# search start at 1111,286
# search start at 518,126
# search start at 214,304
# search start at 1028,254
# search start at 1160,331
# search start at 761,101
# search start at 1214,133
# search start at 833,110
# search start at 486,21
# search start at 622,354
# search start at 642,273
# search start at 1165,186
# search start at 1197,10
# search start at 861,146
# search start at 421,264
# search start at 486,323
# search start at 550,35
# search start at 206,42
# search start at 264,397
# search start at 43,320
# search start at 392,328
# search start at 356,353
# search start at 598,288
# search start at 709,324
# search start at 1136,73
# search start at 694,27
# search start at 322,258
# search start at 525,378
# search start at 281,370
# search start at 32,120
# search start at 456,116
# search start at 1029,225
# search start at 25,321
# search start at 1011,245
# search start at 129,334
# search start at 354,354
# search start at 425,239
# search start at 1194,27
# search start at 1229,268
# search start at 318,154
# search start at 1185,68
# search start at 1160,211
# search start at 111,154
# search start at 20,282
# search start at 1197,15
# search start at 169,299
# search start at 343,183
# search start at 1217,172
# search start at 77,141
# search start at 1160,378
# search start at 496,346
# search start at 980,224
# search start at 1029,48
# search start at 952,156
# search start at 698,166
# search start at 359,289
# search start at 384,41
# search start at 150,15
# search start at 761,234
# search start at 551,325
# search start at 1228,151
# search start at 389,381
# search start at 774,116
# search start at 603,180
# search start at 594,27
# search start at 1121,114
# search start at 578,375
# search start at 618,326
# search start at 81,328
# search start at 1007,340
# search start at 32,358
# search start at 338,80
# search start at 23,41
# search start at 739,357
# search start at 800,317
# search start at 609,47
# search start at 482,158
# search start at 503,49
# search start at 181,244
# search start at 1014,263
# search start at 511,253
# search start at 854,347
# search start at 308,349
# search start at 758,181
# search start at 307,397
# search start at 1225,98
# search start at 132,393
# search start at 1188,390
# search start at 529,76
# search start at 446,21
# search start at 482,218
# search start at 515,188
# search start at 533,234
# search start at 547,109
# search start at 27,41
# search start at 974,345
# search start at 525,361
# search start at 352,242
# search start at 783,194
# search start at 483,385
# search start at 1216,122
# search start at 1166,107
# search start at 971,129
# search start at 22,168
# search start at 526,321
# search start at 228,131
# search start at 266,295
# search start at 107,368
# search start at 164,114
# search start at 546,133
# search start at 616,301
# search start at 501,270
# search start at 332,2
# search start at 846,309
# search start at 604,9
# search start at 985,145
# search start at 367,29
# search start at 655,282
# search start at 7,332
# search start at 1072,21
# search start at 1047,63
# search start at 1002,371
# search start at 1109,228
# search start at 657,344
# search start at 1153,112
# search start at 558,287
# search start at 215,338
# search start at 944,380
# search start at 640,324
# search start at 265,73
# search start at 158,215
# search start at 131,175
# search start at 590,370
# search start at 465,366
# search start at 1197,19
# search start at 1205,182
# search start at 221,201
# search start at 412,198
# search start at 298,186
# search start at 141,68
# search start at 981,362
# search start at 779,318
# search start at 586,309
# search start at 1170,146
# search start at 211,117
# search start at 812,202
# search start at 898,67
# search start at 772,250
# search start at 346,372
# search start at 678,311
# search start at 1027,180
# search start at 227,69
# search start at 1074,364
# search start at 1103,148
# search start at 168,31
# search start at 919,51
# search start at 346,232
# search start at 30,272
# search start at 306,140
# search start at 299,117
# search start at 801,254
# search start at 256,40
# search start at 194,332
# search start at 804,394
# search start at 523,19
# search start at 294,91
# search start at 188,1
# search start at 613,249
# search start at 695,23
# search start at 68,206
# search start at 752,294
# search start at 1073,289
# search start at 919,230
# search start at 884,144
# search start at 844,399
# search start at 976,192
# search start at 776,210
# search start at 698,7
# search start at 108,195
# search start at 1109,314
# search start at 1023,13
# search start at 771,187
# search start at 174,43
# search start at 560,323
# search start at 168,382
# search start at 594,83
# search start at 1066,316
# search start at 438,342
# search start at 583,10
# search start at 152,263
# search start at 1101,82
# search start at 706,50
# search start at 969,170
# search start at 542,194
# search start at 432,225
# search start at 891,109
# search start at 1225,72
# search start at 58,203
# search start at 968,399
# search start at 368,91
# search start at 171,254
# search start at 101,78
# search start at 330,342
# search start at 212,238
# search start at 953,267
# search start at 207,355
# search start at 513,203
# search start at 53,72
# search start at 827,74
# search start at 236,64
# search start at 861,301
# search start at 1037,149
# search start at 807,229
# search start at 891,17
# search start at 944,187
# search start at 833,90
# search start at 267,18
# search start at 1157,298
# search start at 432,388
# search start at 465,101
# search start at 237,269
# search start at 1055,397
# search start at 520,342
# search start at 662,94
# search start at 1186,182
# search start at 875,61
# search start at 388,188
# search start at 1093,400
# search start at 583,80
# search start at 338,223
# search start at 831,312
# search start at 1190,68
# search start at 656,323
# search start at 85,393
# search start at 715,346
# search start at 224,325
# search start at 433,238
# search start at 1037,76
# search start at 929,355
# search start at 512,139
# search start at 741,386
# search start at 80,344
# search start at 182,394
# search start at 495,289
# search start at 900,40
# search start at 59,374
# search start at 937,200
# search start at 1116,104
# search start at 873,85
# search start at 767,127
# search start at 351,40
# search start at 400,43
# search start at 257,170
# search start at 1157,265
# search start at 937,67
# search start at 157,227
# search start at 1206,75
# search start at 852,299
# search start at 212,207
# search start at 249,140
# search start at 1045,128
# search start at 800,274
# search start at 596,96
# search start at 1127,3
# search start at 1137,94
# search start at 650,239
# search start at 104,283
# search start at 382,354
# search start at 208,196
# search start at 298,380
# search start at 810,135
# search start at 382,311
# search start at 1227,261
# search start at 677,48
# search start at 906,338
# search start at 869,45
# search start at 220,202
# search start at 317,387
# search start at 1142,24
# search start at 489,394
# search start at 660,308
# search start at 571,43
# search start at 666,235
# search start at 1151,69
# search start at 292,191
# search start at 325,140
# search start at 676,161
# search start at 383,372
# search start at 991,150
# search start at 507,57
# search start at 1038,116
# search start at 57,157
# search start at 928,367
# search start at 676,175
# search start at 910,272
# search start at 539,241
# search start at 30,245
# search start at 1163,225
# search start at 1097,204
# search start at 451,206
# search start at 1124,32
# search start at 1088,244
# search start at 163,354
# search start at 554,123
# search start at 688,207
# search start at 431,70
# search start at 1217,351
# search start at 231,85
# search start at 745,221
# search start at 361,264
# search start at 41,45
# search start at 668,199
# search start at 59,331
# search start at 892,212
# search start at 557,155
# search start at 643,301
# search start at 330,324
# search start at 568,289
# search start at 1114,30
# search start at 940,304
# search start at 874,13
# search start at 1159,194
# search start at 588,282
# search start at 1222,248
# search start at 605,178
# search start at 400,52
# search start at 336,51
# search start at 1088,338
# search start at 784,140
# search start at 403,374
# search start at 306,113
# search start at 604,316
# search start at 329,39
# search start at 127,271
# search start at 273,377
# search start at 236,77
# search start at 510,75
# search start at 12,391
# search start at 277,152
# search start at 853,146
# search start at 90,226
# search start at 112,376
# search start at 903,30
# search start at 1001,390
# search start at 948,194
# search start at 1137,32
# search start at 352,174
# search start at 846,165
# search start at 528,274
# search start at 380,56
# search start at 371,26
# search start at 260,359
# search start at 486,169
# search start at 427,305
# search start at 85,295
# search start at 893,143
# search start at 203,304
# search start at 202,143
# search start at 193,242
# search start at 1222,141
# search start at 281,195
# search start at 444,350
# search start at 290,355
# search start at 310,164
# search start at 493,195
# search start at 1037,115
# search start at 33,367
# search start at 889,242
# search start at 675,374
# search start at 666,269
# search start at 799,275
# search start at 1082,3
# search start at 935,285
# search start at 638,109
# search start at 1148,66
# search start at 880,44
# search start at 871,210
# search start at 988,358
# search start at 1178,386
# search start at 854,299
# search start at 248,378
# search start at 16,364
# search start at 435,341
# search start at 371,178
# search start at 703,18
# search start at 229,273
# search start at 975,245
# search start at 863,68
# search start at 624,107
# search start at 410,210
# search start at 1047,198
# search start at 133,77
# search start at 335,55
# search start at 1006,73
# search start at 272,218
# search start at 995,64
# search start at 846,15
# search start at 818,252
# search start at 640,70
# search start at 984,391
# search start at 1153,126
# search start at 1142,199
# search start at 1131,6
# search start at 23,108
# search start at 1111,53
# search start at 227,39
# search start at 591,373
# search start at 743,187
# search start at 70,85
# search start at 811,48
# search start at 670,347
# search start at 1111,218
# search start at 1212,157
# search start at 567,287
# search start at 309,121
# search start at 884,388
# search start at 493,6
# search start at 28,117
# search start at 1229,60
# search start at 1193,11
# search start at 31,249
# search start at 328,56
# search start at 594,288
# search start at 508,4
# search start at 354,56
# search start at 194,229
# search start at 355,88
# search start at 553,44
# search start at 162,391
# search start at 646,274
# search start at 929,3
# search start at 946,257
# search start at 131,238
# search start at 730,374
# search start at 813,182
# search start at 620,395
# search start at 483,82
# search start at 307,241
# search start at 936,41
# search start at 1052,232
# search start at 963,257
# search start at 534,16
# search start at 872,365
# search start at 203,111
# search start at 1208,104
# search start at 563,72
# search start at 424,140
# search start at 421,9
# search start at 85,361
# search start at 1088,255
# search start at 76,135
# search start at 825,160
# search start at 476,140
# search start at 882,280
# search start at 840,312
# search start at 263,157
# search start at 628,213
# search start at 371,337
# search start at 752,164
# search start at 1183,15
# search start at 361,240
# search start at 252,62
# search start at 96,329
# search start at 1147,5
# search start at 634,121
# search start at 555,204
# search start at 218,349
# search start at 654,317
# search start at 648,107
# search start at 252,152
# search start at 1113,353
# search start at 748,321
# search start at 59,334
# search start at 512,222
# search start at 1060,165
# search start at 149,205
# search start at 1059,323
# search start at 292,157
# search start at 7,394
# search start at 728,86
# search start at 179,265
# search start at 393,184
# search start at 375,77
# search start at 332,126
# search start at 1071,317
# search start at 1071,104
# search start at 779,91
# search start at 74,204
# search start at 655,392
# search start at 1026,363
# search start at 703,239
# search start at 121,277
# search start at 1151,169
# search start at 1036,351
# search start at 108,70
# search start at 1158,361
# search start at 596,170
# search start at 1157,91
# search start at 760,116
# search start at 616,197
# search start at 169,325
# search start at 764,186
# search start at 42,50
# search start at 931,365
# search start at 1208,103
# search start at 374,14
# search start at 1020,373
# search start at 330,347
# search start at 640,214
# search start at 399,253
# search start at 157,324
# search start at 495,6
# search start at 639,157
# search start at 238,163
# search start at 147,181
# search start at 1190,180
# search start at 1029,57
# search start at 876,333
# search start at 653,389
# search start at 1132,251
# search start at 414,147
# search start at 464,34
# search start at 191,147
# search start at 192,152
# search start at 1064,165
# search start at 950,216
# search start at 812,189
# search start at 289,149
# search start at 710,242
# search start at 152,387
# search start at 925,331
# search start at 760,217
# search start at 125,44
# search start at 855,6
# search start at 173,133
# search start at 489,190
# search start at 74,220
# search start at 440,190
# search start at 613,301
# search start at 766,76
# search start at 430,232
# search start at 817,398
# search start at 577,221
# search start at 657,266
# search start at 606,298
# search start at 215,291
# search start at 164,363
# search start at 350,49
# search start at 381,272
# search start at 872,94
# search start at 181,264
# search start at 1161,212
# search start at 1133,139
# search start at 980,281
# search start at 571,56
# search start at 406,219
# search start at 708,55
# search start at 657,30
# search start at 7,225
# search start at 1144,60
# search start at 1160,370
# search start at 172,292
# search start at 641,310
# search start at 34,59
# search start at 220,2
# search start at 5,29
# search start at 1182,11
# search start at 783,183
# search start at 1041,84
# search start at 799,112
# search start at 244,318
# search start at 268,213
# search start at 890,352
# search start at 1149,57
# search start at 448,164
# search start at 617,178
# search start at 532,301
# search start at 387,253
# search start at 943,4
# search start at 997,107
# search start at 350,145
# search start at 295,12
# search start at 606,78
# search start at 839,246
# search start at 362,314
# search start at 406,137
# search start at 340,355
# search start at 14,368
# search start at 596,131
# search start at 222,131
# search start at 183,104
# search start at 730,374
# search start at 1049,333
# search start at 137,380
# search start at 25,198
# search start at 1043,95
# search start at 499,300
# search start at 266,69
# search start at 1165,219
# search start at 619,25
# search start at 83,360
# search start at 124,358
# search start at 380,381
# search start at 939,60
# search start at 1190,81
# search start at 874,184
# search start at 184,337
# search start at 1005,251
# search start at 359,108
# search start at 361,261
# search start at 1059,144
# search start at 1053,22
# search start at 801,47
# search start at 347,218
# search start at 126,202
# search start at 956,377
# search start at 786,35
# search start at 609,52
# search start at 89,337
# search start at 656,134
# search start at 994,227
# search start at 2,240
# search start at 500,307
# search start at 86,320
# search start at 291,368
# search start at 1215,262
# search start at 622,38
# search start at 1218,331
# search start at 1141,29
# search start at 644,341
# search start at 1054,146
# search start at 656,137
# search start at 644,143
# search start at 1202,366
# search start at 93,235
# search start at 580,139
# search start at 553,281
# search start at 605,26
# search start at 524,383
# search start at 60,306
# search start at 1204,233
# search start at 161,180
# search start at 644,215
# search start at 101,191
# search start at 1058,353
# search start at 400,274
# search start at 594,132
# search start at 1082,203
# search start at 616,274
# search start at 466,355
# search start at 794,337
# search start at 737,370
# search start at 1162,171
# search start at 508,35
# search start at 144,223
# search start at 1158,159
# search start at 883,23
# search start at 116,197
# search start at 196,288
# search start at 641,6
# search start at 255,12
# search start at 877,102
# search start at 177,144
# search start at 1050,115
# search start at 536,170
# search start at 1143,309
# search start at 142,208
# search start at 86,345
# search start at 217,246
# search start at 481,15
# search start at 501,377
# search start at 1200,381
# search start at 538,385
# search start at 806,12
# search start at 211,227
# search start at 128,340
# search start at 1087,54
# search start at 9,94
# search start at 23,310
# search start at 89,8
# search start at 1026,282
# search start at 1223,239
# search start at 205,243
# search start at 397,114
# search start at 747,174
# search start at 1088,30
# search start at 72,216
# search start at 1074,339
# search start at 259,27
# search start at 1171,28
# search start at 763,327
# search start at 605,202
# search start at 674,171
# search start at 863,158
# search start at 283,359
# search start at 36,387
# search start at 663,208
# search start at 394,179
# search start at 100,4
# search start at 243,192
# search start at 86,200
# search start at 626,252
# search start at 457,140
# search start at 987,189
# search start at 1113,240
# search start at 441,148
# search start at 964,257
# search start at 893,78
# search start at 1150,184
# search start at 314,37
# search start at 1056,31
# search start at 933,331
# search start at 751,344
# search start at 278,373
# search start at 61,53
# search start at 250,302
# search start at 501,211
# search start at 263,218
# search start at 587,174
# search start at 310,120
# search start at 849,314
# search start at 789,211
# search start at 1222,285
# search start at 450,207
# search start at 22,266
# search start at 970,303
# search start at 783,260
# search start at 975,114
# search start at 1139,101
# search start at 747,199
# search start at 1070,92
# search start at 66,145
# search start at 731,28
# search start at 624,169
# search start at 576,375
# search start at 16,101
# search start at 553,273
# search start at 543,266
# search start at 119,192
# search start at 384,225
# search start at 178,324
# search start at 738,133
# search start at 1167,129
# search start at 1138,29
# search start at 760,158
# search start at 969,269
# search start at 290,248
# search start at 57,100
# search start at 425,77
# search start at 355,81
# search start at 864,110
# search start at 22,339
# search start at 939,126
# search start at 59,107
# search start at 1128,225
# search start at 539,150
# search start at 152,300
# search start at 105,340
# search start at 258,26
# search start at 396,54
# search start at 1091,322
# search start at 158,299
# search start at 831,85
# search start at 1037,395
# search start at 839,190
# search start at 204,124
# search start at 1006,85
# search start at 777,343
# search start at 1141,26
# search start at 1203,41
# search start at 972,253
# search start at 720,350
# search start at 115,374
# search start at 788,52
# search start at 1058,209
# search start at 864,90
# search start at 1049,65
# search start at 988,62
# search start at 673,129
# search start at 1018,209
# search start at 35,9
# search start at 199,159
# search start at 1218,225
# search start at 153,51
# search start at 780,5
# search start at 1008,178
# search start at 199,23
# search start at 858,54
# search start at 311,394
# search start at 1161,35
# search start at 57,368
# search start at 706,352
# search start at 936,108
# search start at 1051,15
# search start at 346,97
# search start at 275,72
# search start at 1076,58
# search start at 1121,34
# search start at 110,189
# search start at 574,387
# search start at 221,189
# search start at 1149,310
# search start at 411,235
# search start at 833,110
# search start at 1041,67
# search start at 729,276
# search start at 318,70
# search start at 1035,237
# search start at 1204,87
# search start at 242,263
# search start at 123,183
# search start at 127,361
# search start at 936,114
# search start at 1041,182
# search start at 1127,115
# search start at 294,372
# search start at 597,357
# search start at 129,286
# search start at 10,371
# search start at 917,96
# search start at 529,77
# search start at 918,15
# search start at 565,224
# search start at 495,71
# search start at 1016,328
# search start at 342,374
# search start at 794,286
# search start at 36,288
# search start at 1149,87
# search start at 341,215
# search start at 773,115
# search start at 370,23
# search start at 307,299
# search start at 972,388
# search start at 542,367
# search start at 824,136
# search start at 129,165
# search start at 811,97
# search start at 371,275
# search start at 599,399
# search start at 900,1
# search start at 591,194
# search start at 449,392
# search start at 782,50
# search start at 171,152
# search start at 503,124
# search start at 651,66
# search start at 980,289
# search start at 705,4
# search start at 886,298
# search start at 585,82
# search start at 1000,66
# search start at 1035,93
# search start at 700,59
# search start at 445,269
# search start at 146,107
# search start at 634,40
# search start at 1065,15
# search start at 1117,292
# search start at 12,301
# search start at 1112,114
# search start at 164,384
# search start at 844,0
# search start at 24,241
# search start at 14,227
# search start at 680,306
# search start at 1183,329
# search start at 638,384
# search start at 186,198
# search start at 118,229
# search start at 488,181
# search start at 2,141
# search start at 914,107
# search start at 341,350
# search start at 246,12
# search start at 556,60
# search start at 376,181
# search start at 50,132
# search start at 110,186
# search start at 667,329
# search start at 805,198
# search start at 277,190
# search start at 852,379
# search start at 152,25
# search start at 652,373
# search start at 1039,289
# search start at 896,99
# search start at 1058,150
# search start at 640,87
# search start at 96,81
# search start at 872,219
# search start at 710,47
# search start at 454,98
# search start at 100,61
# search start at 1147,16
# search start at 798,53
# search start at 55,256
# search start at 262,213
# search start at 340,169
# search start at 910,78
# search start at 437,258
# search start at 1182,392
# search start at 962,375
# search start at 734,342
# search start at 577,123
# search start at 892,288
# search start at 548,253
# search start at 537,292
# search start at 574,60
# search start at 840,178
# search start at 1011,129
# search start at 607,267
# search start at 59,390
# search start at 798,75
# search start at 21,106
# search start at 1191,249
# search start at 646,60
# search start at 1100,375
# search start at 234,68
# search start at 471,54
# search start at 550,264
# search start at 293,254
# search start at 648,382
# search start at 390,85
# search start at 549,259
# search start at 682,320
# search start at 373,5
# search start at 962,252
# search start at 1001,160
# search start at 484,79
# search start at 439,135
# search start at 420,42
# search start at 487,121
# search start at 565,8
# search start at 753,276
# search start at 461,92
# search start at 847,68
# search start at 395,251
# search start at 335,373
# search start at 246,372
# search start at 1026,376
# search start at 1083,5
# search start at 439,36
# search start at 560,240
# search start at 104,200
# search start at 598,34
# search start at 716,157
# search start at 204,306
# search start at 428,257
# search start at 973,286
# search start at 940,291
# search start at 497,180
# search start at 42,88
# search start at 663,179
# search start at 425,289
# search start at 173,150
# search start at 80,368
# search start at 64,10
# search start at 2,78
# search start at 1226,119
# search start at 809,81
# search start at 670,282
# search start at 541,18
# search start at 597,134
# search start at 770,227
# search start at 512,3
# search start at 705,384
# search start at 648,216
# search start at 1163,312
# search start at 131,197
# search start at 1222,305
# search start at 546,55
# search start at 548,339
# search start at 816,1
# search start at 86,156
# search start at 619,92
# search start at 80,8
# search start at 348,345
# search start at 52,112
# search start at 299,63
# search start at 460,173
# search start at 298,349
# search start at 419,372
# search start at 1085,197
# search start at 974,139
# search start at 69,351
# search start at 303,344
# search start at 109,247
# search start at 716,115
# search start at 1192,185
# search start at 1110,59
# search start at 819,46
# search start at 1078,176
# search start at 156,231
# search start at 1098,193
# search start at 581,231
# search start at 634,350
# search start at 216,247
# search start at 513,120
# search start at 1110,20
# search start at 473,224
# search start at 266,48
# search start at 447,282
# search start at 586,338
# search start at 776,212
# search start at 660,176
# search start at 9,306
# search start at 670,67
# search start at 1133,157
# search start at 650,78
# search start at 403,318
# search start at 995,16
# search start at 933,97
# search start at 103,9
# search start at 612,142
# search start at 723,59
# search start at 806,285
# search start at 1086,26
# search start at 298,312
# search start at 327,268
# search start at 1171,148
# search start at 1166,83
# search start at 409,7
# search start at 918,172
# search start at 362,150
# search start at 683,293
# search start at 999,290
# search start at 546,145
# search start at 1200,79
# search start at 182,45
# search start at 342,241
# search start at 949,105
# search start at 192,274
# search start at 820,217
# search start at 608,107
# search start at 426,162
# search start at 926,336
# search start at 1049,360
# search start at 84,26
# search start at 116,90
# search start at 681,135
# search start at 331,200
# search start at 1068,276
# search start at 27,222
# search start at 230,62
# search start at 566,365
# search start at 144,99
# search start at 1132,347
# search start at 718,362
# search start at 739,270
# search start at 912,144
# search start at 599,122
# search start at 460,318
# search start at 981,70
# search start at 1176,83
# search start at 724,125
# search start at 839,342
# search start at 360,245
# search start at 263,265
# search start at 254,78
# search start at 850,21
# search start at 107,80
# search start at 1075,59
# search start at 315,72
# search start at 389,72
# search start at 581,271
# search start at 33,328
# search start at 259,349
# search start at 543,128
# search start at 719,121
# search start at 661,246
# search start at 102,172
# search start at 1164,84
# search start at 694,140
# search start at 895,324
# search start at 87,216
# search start at 248,187
# search start at 249,202
# search start at 1075,196
# search start at 534,249
# search start at 416,329
# search start at 77,137
# search start at 152,219
# search start at 1213,362
# search start at 714,394
# search start at 1118,371
# search start at 152,209
# search start at 960,162
# search start at 1135,240
# search start at 779,170
# search start at 646,112
# search start at 721,111
# search start at 791,45
# search start at 165,310
# search start at 729,65
# search start at 1217,205
# search start at 163,244
# search start at 1155,231
# search start at 1170,248
# search start at 792,176
# search start at 686,31
# search start at 38,332
# search start at 197,209
# search start at 1216,91
# search start at 1149,287
# search start at 1032,32
# search start at 830,332
# search start at 549,277
# search start at 640,246
# search start at 127,124
# search start at 144,228
# search start at 575,31
# search start at 1140,353
# search start at 880,365
# search start at 102,78
# search start at 283,350
# search start at 802,7
# search start at 572,135
# search start at 301,133
# search start at 596,351
# search start at 1216,6
# search start at 294,259
# search start at 904,61
# search start at 438,268
# search start at 836,92
# search start at 1212,170
# search start at 325,325
# search start at 273,187
# search start at 1215,20
# search start at 382,296
# search start at 394,159
# search start at 771,314
# search start at 1219,349
# search start at 635,70
# search start at 819,100
# search start at 500,365
# search start at 909,6
# search start at 1124,210
# search start at 1108,134
# search start at 257,153
# search start at 457,62
# search start at 106,35
# search start at 118,79
# search start at 262,37
# search start at 170,331
# search start at 552,35
# search start at 79,151
# search start at 401,325
# search start at 482,51
# search start at 779,148
# search start at 126,370
# search start at 1133,304
# search start at 173,19
# search start at 458,34
# search start at 265,210
# search start at 719,245
# search start at 659,261
# search start at 1058,124
# search start at 44,277
# search start at 811,218
# search start at 91,122
# search start at 502,125
# search start at 1123,326
# search start at 789,36
# search start at 1001,155
# search start at 1230,185
# search start at 998,299
# search start at 452,357
# search start at 666,367
# search start at 1142,86
# search start at 737,188
# search start at 234,129
# search start at 198,378
# search start at 198,38
# search start at 82,187
# search start at 557,310
# search start at 668,52
# search start at 381,121
# search start at 1069,185
# search start at 334,118
# search start at 196,128
# search start at 187,206
# search start at 1012,54
# search start at 53,141
# search start at 269,213
# search start at 559,282
# search start at 425,117
# search start at 1059,240
# search start at 1062,137
# search start at 1054,337
# search start at 864,377
# search start at 169,382
# search start at 709,119
# search start at 538,390
# search start at 865,0
# search start at 170,77
# search start at 671,121
# search start at 652,145
# search start at 26,234
# search start at 36,344
# search start at 141,0
# search start at 227,19
# search start at 411,57
# search start at 282,34
# search start at 20,128
# search start at 1083,263
# search start at 1078,339
# search start at 679,74
# search start at 354,115
# search start at 874,194
# search start at 509,119
# search start at 778,360
# search start at 829,308
# search start at 436,263
# search start at 805,221
# search start at 263,98
# search start at 502,272
# search start at 717,296
# search start at 240,263
# search start at 516,162
# search start at 541,101
# search start at 533,250
# search start at 212,228
# search start at 939,343
# search start at 204,221
# search start at 1144,158
# search start at 1160,298
# search start at 324,14
# search start at 1224,16
# search start at 1114,153
# search start at 809,352
# search start at 987,183
# search start at 572,191
# search start at 137,346
# search start at 146,262
# search start at 939,241
# search start at 572,294
# search start at 438,212
# search start at 594,102
# search start at 991,270
# search start at 948,332
# search start at 833,369
# search start at 295,136
# search start at 428,73
# search start at 1010,55
# search start at 958,241
# search start at 619,133
# search start at 467,130
# search start at 912,35
# search start at 252,242
# search start at 751,364
# search start at 749,229
# search start at 126,181
# search start at 651,20
# search start at 406,335
# search start at 842,367
# search start at 259,85
# search start at 86,390
# search start at 1188,134
# search start at 203,382
# search start at 442,58
# search start at 1150,27
# search start at 1067,203
# search start at 1090,388
# search start at 318,58
# search start at 1173,66
# search start at 377,108
# search start at 781,216
# search start at 124,126
# search start at 885,289
# search start at 431,379
# search start at 1094,186
# search start at 616,31
# search start at 456,62
# search start at 416,156
# search start at 695,345
# search start at 23,268
# search start at 842,83
# search start at 593,91
# search start at 678,233
# search start at 1203,171
# search start at 1192,53
# search start at 1047,392
# search start at 228,60
# search start at 1110,213
# search start at 1048,330
# search start at 640,320
# search start at 790,48
# search start at 385,284
# search start at 170,2
# search start at 708,205
# search start at 497,7
# search start at 780,311
# search start at 422,364
# search start at 516,4
# search start at 449,346
# search start at 1190,237
# search start at 777,336
# search start at 514,300
# search start at 593,386
# search start at 196,290
# search start at 509,75
# search start at 270,96
# search start at 974,181
# search start at 731,273
# search start at 994,90
# search start at 255,73
# search start at 1123,361
# search start at 940,140
# search start at 377,209
# search start at 911,248
# search start at 897,315
# search start at 283,86
# search start at 1006,164
# search start at 885,258
# search start at 864,386
# search start at 1007,105
# search start at 898,228
# search start at 978,261
# search start at 503,275
# search start at 298,361
# search start at 658,88
# search start at 189,365
# search start at 38,66
# search start at 826,295
# search start at 916,400
# search start at 371,242
# search start at 958,45
# search start at 193,386
# search start at 895,78
# search start at 731,233
# search start at 1119,389
# search start at 94,41
# search start at 1200,305
# search start at 612,192
# search start at 1093,261
# search start at 934,54
# search start at 975,272
# search start at 620,313
# search start at 190,102
# search start at 417,186
# search start at 816,205
# search start at 323,79
# search start at 82,156
# search start at 786,296
# search start at 411,293
# search start at 55,259
# search start at 694,380
# search start at 804,389
# search start at 258,126
# search start at 0,386
# search start at 131,88
# search start at 409,329
# search start at 252,385
# search start at 87,179
# search start at 193,325
# search start at 569,214
# search start at 373,252
# search start at 627,362
# search start at 165,50
# search start at 880,219
# search start at 53,247
# search start at 1008,226
# search start at 146,151
# search start at 282,354
# search start at 449,342
# search start at 1117,330
# search start at 77,201
# search start at 424,271
# search start at 487,354
# search start at 349,219
# search start at 984,343
# search start at 821,41
# search start at 273,396
# search start at 854,130
# search start at 65,93
# search start at 1142,173
# search start at 1188,385
# search start at 950,107
# search start at 978,182
# search start at 541,296
# search start at 124,113
# search start at 215,320
# search start at 431,282
# search start at 556,262
# search start at 209,395
# search start at 184,21
# search start at 631,244
# search start at 195,4
# search start at 545,287
# search start at 1138,32
# search start at 536,201
# search start at 231,324
# search start at 950,56
# search start at 1033,175
# search start at 12,330
# search start at 299,31
# search start at 580,8
# search start at 944,202
# search start at 180,154
# search start at 379,309
# search start at 182,166
# search start at 201,74
# search start at 948,135
# search start at 701,68
# search start at 889,16
# search start at 954,145
# search start at 81,354
# search start at 963,95
# search start at 441,378
# search start at 412,242
# search start at 165,211
# search start at 366,218
# search start at 219,80
# search start at 1011,297
# search start at 377,260
# search start at 158,30
# search start at 685,361
# search start at 681,240
# search start at 896,381
# search start at 319,62
# search start at 1120,18
# search start at 991,127
# search start at 1220,137
# search start at 1205,355
# search start at 1101,132
# search start at 624,83
# search start at 865,220
# search start at 665,218
# search start at 916,236
# search start at 290,207
# search start at 1070,113
# search start at 472,347
# search start at 1181,131
# search start at 36,174
# search start at 28,312
# search start at 870,232
# search start at 840,52
# search start at 456,334
# search start at 499,56
# search start at 294,373
# search start at 746,71
# search start at 266,180
# search start at 66,262
# search start at 421,362
# search start at 503,106
# search start at 329,215
# search start at 604,72
# search start at 491,335
# search start at 416,372
# search start at 231,335
# search start at 463,123
# search start at 1,178
# search start at 489,292
# search start at 70,112
# search start at 769,268
# search start at 444,234
# search start at 569,251
# search start at 593,209
# search start at 19,32
# search start at 1022,347
# search start at 771,262
# search start at 900,39
# search start at 658,74
# search start at 929,245
# search start at 690,317
# search start at 295,264
# search start at 630,360
# search start at 566,324
# search start at 941,32
# search start at 128,314
# search start at 513,135
# search start at 581,344
# search start at 1082,21
# search start at 1098,58
# search start at 661,178
# search start at 63,97
# search start at 1061,54
# search start at 1095,296
# search start at 849,187
# search start at 1047,63
# search start at 555,341
# search start at 887,362
# search start at 498,359
# search start at 736,168
# search start at 130,329
# search start at 974,351
# search start at 225,272
# search start at 53,212
# search start at 6,88
# search start at 57,364
# search start at 1182,283
# search start at 149,285
# search start at 866,367
# search start at 1123,183
# search start at 121,182
# search start at 318,362
# search start at 728,319
# search start at 719,99
# search start at 801,2
# search start at 525,374
# search start at 646,74
# search start at 756,392
# search start at 349,348
# search start at 476,364
# search start at 1149,17
# search start at 410,137
# search start at 1222,340
# search start at 822,157
# search start at 162,320
# search start at 1220,60
# search start at 606,332
# search start at 526,334
# search start at 69,313
# search start at 951,150
# search start at 1072,353
# search start at 1142,260
# search start at 201,146
# search start at 734,302
# search start at 277,131
# search start at 731,292
# search start at 853,359
# search start at 1100,104
# search start at 894,298
# search start at 196,224
# search start at 785,215
# search start at 37,297
# search start at 55,329
# search start at 1019,210
# search start at 444,273
# search start at 407,106
# search start at 1052,0
# search start at 910,250
# search start at 1198,145
# search start at 686,111
# search start at 430,396
# search start at 383,338
# search start at 371,357
# search start at 1035,145
# search start at 965,140
# search start at 428,173
# search start at 275,227
# search start at 551,319
# search start at 682,137
# search start at 120,390
# search start at 196,116
# search start at 818,318
# search start at 360,257
# search start at 977,24
# search start at 1104,182
# search start at 70,399
# search start at 1115,179
# search start at 923,395
# search start at 83,248
# search start at 748,262
# search start at 911,261
# search start at 691,169
# search start at 727,44
# search start at 122,352
# search start at 723,14
# search start at 729,312
# search start at 1208,20
# search start at 929,312
# search start at 834,182
# search start at 595,134
# search start at 222,194
# search start at 876,199
# search start at 370,219
# search start at 1062,361
# search start at 1099,27
# search start at 464,279
# search start at 290,370
# search start at 407,165
# search start at 1218,223
# search start at 853,218
# search start at 184,137
# search start at 797,344
# search start at 748,142
# search start at 923,161
# search start at 37,255
# search start at 65,279
# search start at 966,102
# search start at 617,20
# search start at 160,129
# search start at 852,216
# search start at 1054,305
# search start at 362,300
# search start at 612,374
# search start at 66,300
# search start at 658,296
# search start at 200,133
# search start at 492,11
# search start at 123,14
# search start at 1123,99
# search start at 1121,66
# search start at 1073,228
# search start at 623,124
# search start at 1179,187
# search start at 383,342
# search start at 16,192
# search start at 957,338
# search start at 1066,162
# search start at 650,299
# search start at 526,108
# search start at 1139,291
# search start at 1116,357
# search start at 919,396
# search start at 237,20
# search start at 436,318
# search start at 903,0
# search start at 720,256
# search start at 466,286
# search start at 357,136
# search start at 169,103
# search start at 981,64
# search start at 1136,155
# search start at 935,249
# search start at 1043,254
# search start at 1011,68
# search start at 310,154
# search start at 824,270
# search start at 560,70
# search start at 406,210
# search start at 948,204
# search start at 123,116
# search start at 406,313
# search start at 98,39
# search start at 498,338
# search start at 160,311
# search start at 888,309
# search start at 1013,311
# search start at 161,115
# search start at 347,298
# search start at 893,284
# search start at 171,352
# search start at 362,368
# search start at 505,114
# search start at 240,367
# search start at 194,271
# search start at 658,290
# search start at 569,337
# search start at 1067,268
# search start at 169,344
# search start at 296,63
# search start at 350,183
# search start at 1076,4
# search start at 274,45
# search start at 1223,59
# search start at 904,179
# search start at 1172,261
# search start at 843,315
# search start at 495,196
# search start at 1035,245
# search start at 697,379
# search start at 425,222
# search start at 904,239
# search start at 84,283
# search start at 64,350
# search start at 6,204
# search start at 242,95
# search start at 682,317
# search start at 223,371
# search start at 1102,191
# search start at 408,386
# search start at 428,86
# search start at 393,372
# search start at 1114,245
# search start at 790,109
# search start at 586,339
# search start at 544,42
# search start at 951,377
# search start at 693,160
# search start at 1055,296
# search start at 68,171
# search start at 353,164
# search start at 425,187
# search start at 393,12
# search start at 332,144
# search start at 785,290
# search start at 486,26
# search start at 292,104
# search start at 230,248
# search start at 413,277
# search start at 914,85
# search start at 327,133
# search start at 546,390
# search start at 585,16
# search start at 654,185
# search start at 379,172
# search start at 690,131
# search start at 494,191
# search start at 349,291
# search start at 564,382
# search start at 1118,285
# search start at 350,256
# search start at 1060,300
# search start at 726,38
# search start at 205,139
# search start at 0,150
# search start at 1197,224
# search start at 1068,338
# search start at 307,239
# search start at 730,31
# search start at 537,150
# search start at 462,337
# search start at 5,362
# search start at 527,193
# search start at 228,240
# search start at 673,219
# search start at 21,38
# search start at 800,148
# search start at 800,152
# search start at 657,291
# search start at 956,238
# search start at 953,187
# search start at 1013,85
# search start at 988,110
# search start at 888,162
# search start at 899,385
# search start at 974,133
# search start at 786,120
# search start at 1074,36
# search start at 151,257
# search start at 1215,367
# search start at 444,140
# search start at 540,315
# search start at 377,211
# search start at 226,81
# search start at 162,397
# search start at 786,230
# search start at 165,354
# search start at 345,147
# search start at 593,367
# search start at 954,6
# search start at 803,353
# search start at 54,83
# search start at 528,335
# search start at 228,217
# search start at 680,367
# search start at 847,394
# search start at 1012,360
# search start at 986,362
# search start at 1206,136
# search start at 1069,313
# search start at 739,17
# search start at 1058,215
# search start at 1044,118
# search start at 713,134
# search start at 1082,125
# search start at 1221,308
# search start at 940,214
# search start at 771,130
# search start at 234,202
# search start at 444,21
# search start at 768,196
# search start at 460,153
# search start at 563,286
# search start at 666,124
# search start at 1141,29
# search start at 758,43
# search start at 959,215
# search start at 351,342
# search start at 258,172
# search start at 1071,140
# search start at 712,12
# search start at 629,256
# search start at 382,391
# search start at 61,360
# search start at 527,70
# search start at 363,285
# search start at 1181,39
# search start at 232,211
# search start at 153,280
# search start at 168,308
# search start at 544,25
# search start at 831,205
# search start at 1114,323
# search start at 882,339
# search start at 778,4
# search start at 60,318
# search start at 111,18
# search start at 1112,160
# search start at 100,98
# search start at 667,112
# search start at 849,13
# search start at 1224,78
# search start at 418,291
# search start at 1112,76
# search start at 407,47
# search start at 610,227
# search start at 691,214
# search start at 129,90
# search start at 154,186
# search start at 1159,205
# search start at 842,94
# search start at 365,65
# search start at 894,130
# search start at 1151,253
# search start at 608,115
# search start at 750,109
# search start at 646,30
# search start at 916,248
# search start at 1159,287
# search start at 474,199
# search start at 560,276
# search start at 1129,329
# search start at 832,395
# search start at 297,79
# search start at 270,150
# search start at 247,263
# search start at 138,164
# search start at 987,41
# search start at 400,156
# search start at 288,395
# search start at 1166,18
# search start at 525,362
# search start at 736,336
# search start at 612,83
# search start at 102,161
# search start at 654,168
# search start at 200,180
# search start at 391,232
# search start at 671,20
# search start at 467,183
# search start at 1056,175
# search start at 1017,359
# search start at 176,246
# search start at 322,7
# search start at 1172,269
# search start at 528,73
# search start at 1145,384
# search start at 60,185
# search start at 719,113
# search start at 538,279
# search start at 199,2
# search start at 1204,165
# search start at 632,176
# search start at 254,62
# search start at 535,313
# search start at 412,339
# search start at 1138,3
# search start at 299,356
# search start at 794,295
# search start at 769,248
# search start at 641,334
# search start at 1030,229
# search start at 1107,245
# search start at 488,21
# search start at 918,45
# search start at 501,81
# search start at 484,176
# search start at 325,337
# search start at 1170,108
# search start at 733,294
# search start at 954,74
# search start at 588,71
# search start at 473,229
# search start at 727,219
# search start at 1102,130
# search start at 525,22
# search start at 39,399
# search start at 1186,272
# search start at 740,171
# search start at 911,138
# search start at 800,196
# search start at 158,380
# search start at 651,169
# search start at 615,154
# search start at 1027,74
# search start at 108,163
# search start at 425,252
# search start at 149,248
# search start at 425,244
# search start at 1205,16
# search start at 578,394
# search start at 541,25
# search start at 700,25
# search start at 78,18
# search start at 1186,389
# search start at 752,225
# search start at 1011,205
# search start at 577,124
# search start at 1029,31
# search start at 916,266
# search start at 891,234
# search start at 1099,209
# search start at 266,4
# search start at 937,348
# search start at 152,78
# search start at 597,191
# search start at 269,398
# search start at 601,335
# search start at 521,294
# search start at 86,217
# search start at 373,379
# search start at 1139,122
# search start at 609,53
# search start at 1151,150
# search start at 925,123
# search start at 723,91
# search start at 828,346
# search start at 969,249
# search start at 83,353
# search start at 892,380
# search start at 136,251
# search start at 244,347
# search start at 898,291
# search start at 1014,137
# search start at 1123,176
# search start at 490,75
# search start at 673,111
# search start at 0,158
# search start at 718,52
# search start at 249,356
# search start at 891,285
# search start at 426,346
# search start at 705,127
# search start at 1133,132
# search start at 605,289
# search start at 647,275
# search start at 932,13
# search start at 297,282
# search start at 664,286
# search start at 181,103
# search start at 1071,346
# search start at 933,158
# search start at 730,137
# search start at 1151,292
# search start at 326,67
# search start at 500,26
# search start at 934,157
# search start at 44,90
# search start at 796,348
# search start at 103,133
# search start at 704,22
# search start at 1148,217
# search start at 31,127
# search start at 1201,58
# search start at 307,265
# search start at 58,246
# search start at 1129,122
# search start at 1217,215
# search start at 1015,360
# search start at 188,370
# search start at 1230,29
# search start at 648,253
# search start at 824,364
# search start at 29,105
# search start at 1173,196
# search start at 162,252
# search start at 862,285
# search start at 524,14
# search start at 637,223
# search start at 677,140
# search start at 478,375
# search start at 10,263
# search start at 746,43
# search start at 155,235
# search start at 849,170
# search start at 159,212
# search start at 178,364
# search start at 735,380
# search start at 728,206
# search start at 741,86
# search start at 956,287
# search start at 879,216
# search start at 568,89
# search start at 496,362
# search start at 270,83
# search start at 568,334
# search start at 295,394
# search start at 73,305
# search start at 954,129
# search start at 42,203
# search start at 610,221
# search start at 177,247
# search start at 339,304
# search start at 52,345
# search start at 140,249
# search start at 401,347
# search start at 1034,244
# search start at 760,276
# search start at 986,106
# search start at 306,266
# search start at 1161,108
# search start at 1057,330
# search start at 746,363
# search start at 958,73
# search start at 1081,228
# search start at 805,236
# search start at 1047,210
# search start at 700,366
# search start at 1079,256
# search start at 487,77
# search start at 1109,53
# search start at 1113,140
# search start at 1225,301
# search start at 1200,276
# search start at 712,320
# search start at 580,328
# search start at 805,105
# search start at 1004,5
# search start at 837,264
# search start at 109,194
# search start at 952,89
# search start at 1106,189
# search start at 440,183
# search start at 896,256
# search start at 413,199
# search start at 840,362
# search start at 711,155
# search start at 994,88
# search start at 658,130
# search start at 362,35
# search start at 803,220
# search start at 225,235
# search start at 1084,323
# search start at 99,376
# search start at 1093,291
# search start at 130,141
# search start at 1191,383
# search start at 234,320
# search start at 540,362
# search start at 878,341
# search start at 591,240
# search start at 194,27
# search start at 362,0
# search start at 181,27
# search start at 1051,213
# search start at 380,355
# search start at 1230,210
# search start at 1130,112
# search start at 1165,309
# search start at 369,360
# search start at 186,142
# search start at 468,22
# search start at 668,311
# search start at 1196,263
# search start at 275,150
# search start at 1038,206
# search start at 929,191

# %%
total_len = 300000
LEN_EASY = total_len*0.2
LEN_INTER = total_len*0.4
LEN_HARD = total_len*0.4

# %%
easy_index = easy_index.reshape(5000)
intermidiate_index = intermidiate_index.reshape(5000)
hard_index = hard_index.reshape(5000)

# %%
def find_paths(paths, indexs, goal):
    i = 0
    sum_len = 0
    while sum_len < goal:
        sum_len += length(paths[indexs[i]])
        i += 1
    return i

# %%
num_easy = find_paths(easy_paths, easy_index, LEN_EASY)
num_inter = find_paths(intermidiate_paths, intermidiate_index, LEN_INTER)
num_hard = find_paths(hard_paths, hard_index, LEN_HARD)

# %%
fig = generate_fig([easy_paths[i] for i in easy_index[:num_easy]], trace)
py.iplot(fig, filename='easy level paths')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /anaconda/envs/py35/lib/python3.5/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw/4.embed" height="525px" width="100%"></iframe>

# %%
fig = generate_fig([intermidiate_paths[i] for i in intermidiate_index[:num_inter]], trace)
py.iplot(fig, filename='intermidiate level paths')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /anaconda/envs/py35/lib/python3.5/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw/6.embed" height="525px" width="100%"></iframe>

# %%
fig = generate_fig([hard_paths[i] for i in hard_index[:num_hard]], trace)
py.iplot(fig, filename='difficult level paths')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /anaconda/envs/py35/lib/python3.5/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw/8.embed" height="525px" width="100%"></iframe>

# %%
num_easy, num_inter, num_hard
# Out:
# (6, 9, 11)
